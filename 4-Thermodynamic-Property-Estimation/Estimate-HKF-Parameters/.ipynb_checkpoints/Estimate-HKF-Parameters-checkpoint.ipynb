# %% [markdown]
# <left>
# <table style="margin-top:0px; margin-left:0px;">
# <tr>
#   <td><img src="https://raw.githubusercontent.com/worm-portal/WORM-Figures/master/style/worm.png" alt="WORM" title="WORM" width=50/></td>
#   <td><h1 style=font-size:30px>Estimating Thermodynamic Properties</h1><h2>Helgeson-Kirkham-Flowers (HKF) Parameters</h2></td>
# </tr>
# </table>
# </left>

# %% [markdown]
# ### What is the HKF equation of state?
#
# The Helgeson-Kirkham-Flowers (HKF) equation of state is widely used in aqueous geochemistry to model how the standard state Gibbs free energies of formation of solutes change with temperature and pressure. The equation is used by WORM tools like pyCHNOSZ and AqEquil to calculate reaction properties such as equilibrium constants at elevated temperatures and pressures.
#
# The HKF equation requires seven parameters that depend on the aqueous species that is being modeled.
#
# |**Symbol**|**Description**|
# |:---:|:---:|
# | $\omega$ | omega, the Born solvation coeffcient |
# | $a_1, a_2, a_3, a_4$ | the pressure-dependence parameters |
# | $c_1, c_2$ | the temperature-dependence parameters |
#
# Most aqueous chemical species in the [WORM thermodynamic database](https://worm-portal.asu.edu/docs/database/) have values for all seven HKF parameters in addition to standard state properties like Gibbs free energy of formation (G), enthalpy (H), third law entropy (S), volume (V), and heat capacity (Cp).
#
# **Note:** Non-aqueous molecules do not use HKF parameters. Instead, non-aqueous use a different equation called the Maier-Kelley equation of state. This equation of state has its own parameters ($a, b, c, d, e, f, \lambda$ (lambda)). The WORM database has entries for crystalline and gaseous chemical species. Their Maier-Kelley coefficients share columns with aqueous HKF coefficients. For example, the HKF omega parameter for an aqueous species shares the same column as the Maier-Kelley lambda parameter, so the column name is "omega.lambda". [This is described in more detail here.](https://worm-portal.asu.edu/docs/database/)
#
# ---
#
# ### Estimating HKF paramters for a new aqueous molecule
#
# Let's say you're interested in obtaining an equilibrium constant for a reaction at elevated temperatures and pressures using the HKF equation (e.g. while using pyCHNOSZ or AqEquil). However, you realize that one of the molecules in your reaction is not in the thermodynamic database. For example, let's assume that aqueous **hexanoic acid** is missing from the database.
#
# Normally, this would not be a problem. The aqueous organic estimator (AqOrg) tool on WORM was built to estimate properties and HKF parameters of aqueous organic nonelectrolytes (see demos 4-1-1 and 4-1-2 in the WORM Library). Aqueous hexanoic acid is an organic nonelectrolyte, so it seems like a perfect candidate for AqOrg. Unfortunately for us, there are no published methods for estimating the properties of a carboxylic acid functional group compatible with the group additivity scheme used by AqOrg. As a result, AqOrg will throw a big red error message saying that it cannot estimate the properties of hexanoic acid. 😔
#
# So what now? Are we stuck? Not necessarily!
#
# Digging through the literature, you'll be able to find experimental measurements of standard state properties that people have published for hexanoic acid at 25 °C and 1 bar. Let's say you gather these:
#
# <center><b>Aqueous Hexanoic Acid</b></center>
#
# |**Value**|**Unit**|**Standard State Property**|**Symbol**|
# |:---:|:---:|:---:|:---:|
# |-87080|cal/mol|Gibbs free energy of formation|$\Delta_f G^{\circ}$|
# |-139290|cal/mol|enthalpy of formation|$\Delta_f H^{\circ}$|
# |69.5|cal/K/mol|third law entropy|$S^{\circ}$|
# |116.55|cm$^3$/mol|volume|$V^{\circ}$|
# |125.2|cal/mol/K|isobaric heat capacity|$C_p^{\circ}$|
#
# It's a great start that allows you to calculate properties of reactions at 25 °C and 1 bar... but what about higher temperatures and pressures? We'll need HKF parameters for that.
#
# Fortunately, there are published strategies for estimating HKF paramters based on 25 °C and 1 bar standard state properties of aqueous molecules. These strategies are outlined in works such as [Shock and Helgeson 1988](https://doi.org/10.1016/0016-7037(88)90181-0) (for ionic species), [Shock and Helgeson 1990](https://doi.org/10.1016/0016-7037(90)90429-O) (for organic electrolytes and nonelectrolytes), [Plyasunov and Shock 2001](https://doi.org/10.1016/S0016-7037(01)00678-0) (for nonelectrolytes when starting with hydration properties), and [Sverjensky et al., 2014](https://doi.org/10.1016/j.gca.2013.12.019) (for solutes used with the Deep Earth Water, DEW, model).
#
# These strategies have been coded into a function called `find_HKF` that is included in the `WORMutils` package. Let's use this function to estimate the HKF parameters of hexanoic acid!
#
# First, let's load some functions from the `WORMutils` package. We'll load a couple of functions; `find_HKF` and another called `find_HKF_test` that will be discussed a little later.

# %%
from WORMutils import find_HKF, find_HKF_test

# %% [markdown]
# Now we can input the 25 °C and 1 bar standard state properties of hexanoic acid into the `find_HKF` function along with charge and whether the molecule is organic:

# %%
hkf, eq = find_HKF(Gf = -87080, # Gibbs free energy of formation, cal/mol
                   Hf = -139290, # enthalpy of formation, cal/mol
                   Saq = 69.5, # third law entropy, cal/mol/K
                   V = 116.55, # volume, cm3/mol
                   Cp = 125.2, # isobaric heat capacity, cal/mol/K
                   Z = 0, # charge
                   organic = True, # is the molecule organic?
                  )

# %% [markdown]
# The `find_HKF` function produces two outputs:
# - The first is the suite of estimated HKF properties (stored in the `hkf` variable, above)
# - The second is a step-by-step list of the published equations used to obtain the estimates.
#
# Let's take a look at the first output:

# %%
hkf
# Out:
# {'G': -87080,
#  'H': -139290,
#  'S': 69.5,
#  'Cp': 125.2,
#  'V': 116.55,
#  'a1': 17.472900047747455,
#  'a2': 26.806012556784516,
#  'a3': 12.5390760363697,
#  'a4': -3.8871605590974725,
#  'c1': 109.67520456912254,
#  'c2': 4.409519999999999,
#  'omega': -0.7125080000000001,
#  'Z': 0,
#  'Vs': 1.759733646978532,
#  'Vn': 114.79026635302147,
#  'sigma': 116.22514468243423}

# %% [markdown]
# The first few lines show the properties that we input into the function, like Gibbs free energy, enthalpy, etc.
#
# The estimated values for the HKF parameters a1-a4, c1-c2, and omega are included.
#
# **VERY IMPORTANT NOTE:** the values of HKF parameters output by `find_HKF` are scaled according to common convention. Scaling conventions and HKF parameter units are shown in the second table [on the webpage that describes the WORM database](https://worm-portal.asu.edu/docs/database/). For example, the estimated value of omega is for hexanoic acid is shown above as $-0.712$, which actually means $\omega = -0.712 \cdot 10^{5}$ cal/mol because by convention, omega values are reported as $\omega \cdot 10^{-5}$. Be aware that each HKF parameter is scaled by a different magnitude:
#
#
# |**output name**|**scaling**|**unit**|
# |:---:|:---:|:---:|
# |omega|$\omega \cdot 10^{5}$|cal/mol|
# |a1|$a_1 \cdot 10$|cal/mol/bar|
# |a2|$a_2 \cdot 10^{-2}$|cal/mol|
# |a3|$a_3$ (no scaling)|(cal*K)/mol/bar|
# |a4|$a_4 \cdot 10^{-4}$|(cal*K)/mol|
# |c1|$c_1$ (no scaling)|cal/mol/K|
# |c2|$c_2 \cdot 10^{-4}$|(cal*K)/mol|
#
# Why are HKF parameters scaled like this? Traditionally, it was done to make tables of HKF parameters look tidier in published papers.
#
# The upside of having the `find_HKF` function output scaled HKF parameters is that you can plug these numbers directly into the WORM database when creating a custom CSV for your own research. For example, the "omega.lambda" column, which contains the omega parameter for aqueous species, requires that scaled values be entered according to $\omega \cdot 10^{-5}$. In other words, you don't have to scale HKF parameters yourself,  and can enter them as-is into the WORM database.
#
# Now let's look at the second output of `find_HKF`:

# %%
eq
# Out:
# ['eta = 166027.0 angstroms*cal/mol, Y = -5.802e-05 1/K, Q = 5.903e-07 (1/bar), X = -3.09e-07 1/K**2',
#  'abs_protonBorn = 0.5387 * 10**5 cal/mol, mentioned in text after Eq 47 in Shock and Helgeson 1988',
#  'Gh is not provided and charge equals zero so estimate omega for neutral solutes from Shock and Helgeson 1990...',
#  'omega = -71251 cal/mol = -1514.4*Saq + 0.34*10**5, Eq 61 in Shock and Helgeson 1990',
#  'Vs = 1.7597 cm3/mol = -omega*Q*conv, Eq 5 in Shock and Helgeson 1988, delta V solvation',
#  'Vn cm3/mol = 114.79 cm3/mol = V - Vs, Eq 4 in Shock and Helgeson 1988, delta V nonsolvation',
#  'Cps = 6.5642 cal/mol/K= omega*Tr*X, Eq 35 in Shock and Helgeson 1988, delta Cp solvation',
#  'Cpn = 118.64 cal/mol/K = Cp - Cps, Eq 29 in Shock and Helgeson 1988, delta Cp nonsolvation',
#  'Gh is unavailable and/or charge is not 0',
#  'a1 = 1.7473 cal/mol/bar = 1.3684E-2*Vn+0.1765, Eq 85 in Shock and Helgeson 1988',
#  'sigma cm3/mol = 116.23 cm3/mol = 1.0125*Vn, Eq 63 in Shock and Helgeson 1990',
#  'a2 = 2680.6 cal/mol = (sigma/conv-a1)*pfunk, Eq 8 in Shock and Helgeson 1988, rearranged to solve for a2',
#  'a4 = -38872 (cal*K)/mol = -4.134*a2-27790, Eq 88 in Shock and Helgeson 1988',
#  'c2 = 44095 (cal*K)/mol = (0.0676*Cp - 4.054)/10**-4, Eq 64 in Shock and Helgeson 1990',
#  'c1 = 109.68 cal/mol/K = Cpn-((c2*(1/(Tr-theta))**2), Eq 31 in Shock and Helgeson 1988, rearranged to solve for c1',
#  'a3 = 12.539 (cal*K)/mol/bar = ((Vn/conv)-a1-a2/pfunk)*(Tr-theta)-(a4/pfunk), after Eq 11 in Shock and Helgeson 1988, rearranged to solve for a3.']

# %% [markdown]
# We can get a neater version of this by setting up a little loop to print each line:

# %%
for equation in eq:
    print(equation)
# Out:
# eta = 166027.0 angstroms*cal/mol, Y = -5.802e-05 1/K, Q = 5.903e-07 (1/bar), X = -3.09e-07 1/K**2
# abs_protonBorn = 0.5387 * 10**5 cal/mol, mentioned in text after Eq 47 in Shock and Helgeson 1988
# Gh is not provided and charge equals zero so estimate omega for neutral solutes from Shock and Helgeson 1990...
# omega = -71251 cal/mol = -1514.4*Saq + 0.34*10**5, Eq 61 in Shock and Helgeson 1990
# Vs = 1.7597 cm3/mol = -omega*Q*conv, Eq 5 in Shock and Helgeson 1988, delta V solvation
# Vn cm3/mol = 114.79 cm3/mol = V - Vs, Eq 4 in Shock and Helgeson 1988, delta V nonsolvation
# Cps = 6.5642 cal/mol/K= omega*Tr*X, Eq 35 in Shock and Helgeson 1988, delta Cp solvation
# Cpn = 118.64 cal/mol/K = Cp - Cps, Eq 29 in Shock and Helgeson 1988, delta Cp nonsolvation
# Gh is unavailable and/or charge is not 0
# a1 = 1.7473 cal/mol/bar = 1.3684E-2*Vn+0.1765, Eq 85 in Shock and Helgeson 1988
# sigma cm3/mol = 116.23 cm3/mol = 1.0125*Vn, Eq 63 in Shock and Helgeson 1990
# a2 = 2680.6 cal/mol = (sigma/conv-a1)*pfunk, Eq 8 in Shock and Helgeson 1988, rearranged to solve for a2
# a4 = -38872 (cal*K)/mol = -4.134*a2-27790, Eq 88 in Shock and Helgeson 1988
# c2 = 44095 (cal*K)/mol = (0.0676*Cp - 4.054)/10**-4, Eq 64 in Shock and Helgeson 1990
# c1 = 109.68 cal/mol/K = Cpn-((c2*(1/(Tr-theta))**2), Eq 31 in Shock and Helgeson 1988, rearranged to solve for c1
# a3 = 12.539 (cal*K)/mol/bar = ((Vn/conv)-a1-a2/pfunk)*(Tr-theta)-(a4/pfunk), after Eq 11 in Shock and Helgeson 1988, rearranged to solve for a3.

# %% [markdown]
# These are the equations and constants that were used to estimate the HKF parameters of hexanoic acid. Equations are shown with source references, and the value and units that have been calculated at each step. Equations are shown in the order that they were used. Math operations are shown pythonically (e.g., 0.34*10\**5 represents $0.34 \cdot 10^{5}$).
#
# Note that there are a couple of literature sources used in this example: [Shock and Helgeson 1988](https://doi.org/10.1016/0016-7037(88)90181-0) and [Shock and Helgeson 1990](https://doi.org/10.1016/0016-7037(90)90429-O). This is because certain equations from the first source are also used in the second.
#
# ---
#
# If you are curious about how well the `find_HKF` function is able to replicate published HKF parameters, check out the `find_HKF_test` function. It reports inputs and outputs for various aqueous species and compares output to published values.

# %%
find_HKF_test()
# Out:
# SELECT ITEMS FROM SHOCK AND HELGESON 1990, TABLE 6
# ---------------------------------------------
#
# hexanoic acid
# ---------
# Input parameters:
# V=116.55, Cp=125.2, Gf=-87080, Hf=-139290, Saq=69.5, Z=0, organic=True
#
# Published: -0.7125, 	Calculated: -0.7125, 	omega*10**-5
# Published: 17.4729, 	Calculated: 17.4729, 	a1*10
# Published: 26.8090, 	Calculated: 26.806, 	a2*10**-2
# Published: 12.5312, 	Calculated: 12.5391, 	a3
# Published: -3.8872, 	Calculated: -3.8872, 	a4*10**-4
# Published: 109.6753, 	Calculated: 109.68, 	c1
# Published: 4.4095, 	Calculated: 4.4095, 	c2*10**-4
#
# eta = 166027.0 angstroms*cal/mol, Y = -5.802e-05 1/K, Q = 5.903e-07 (1/bar), X = -3.09e-07 1/K**2
# abs_protonBorn = 0.5387 * 10**5 cal/mol, mentioned in text after Eq 47 in Shock and Helgeson 1988
# Gh is not provided and charge equals zero so estimate omega for neutral solutes from Shock and Helgeson 1990...
# omega = -71251 cal/mol = -1514.4*Saq + 0.34*10**5, Eq 61 in Shock and Helgeson 1990
# Vs = 1.7597 cm3/mol = -omega*Q*conv, Eq 5 in Shock and Helgeson 1988, delta V solvation
# Vn cm3/mol = 114.79 cm3/mol = V - Vs, Eq 4 in Shock and Helgeson 1988, delta V nonsolvation
# Cps = 6.5642 cal/mol/K= omega*Tr*X, Eq 35 in Shock and Helgeson 1988, delta Cp solvation
# Cpn = 118.64 cal/mol/K = Cp - Cps, Eq 29 in Shock and Helgeson 1988, delta Cp nonsolvation
# Gh is unavailable and/or charge is not 0
# a1 = 1.7473 cal/mol/bar = 1.3684E-2*Vn+0.1765, Eq 85 in Shock and Helgeson 1988
# sigma cm3/mol = 116.23 cm3/mol = 1.0125*Vn, Eq 63 in Shock and Helgeson 1990
# a2 = 2680.6 cal/mol = (sigma/conv-a1)*pfunk, Eq 8 in Shock and Helgeson 1988, rearranged to solve for a2
# a4 = -38872 (cal*K)/mol = -4.134*a2-27790, Eq 88 in Shock and Helgeson 1988
# c2 = 44095 (cal*K)/mol = (0.0676*Cp - 4.054)/10**-4, Eq 64 in Shock and Helgeson 1990
# c1 = 109.68 cal/mol/K = Cpn-((c2*(1/(Tr-theta))**2), Eq 31 in Shock and Helgeson 1988, rearranged to solve for c1
# a3 = 12.539 (cal*K)/mol/bar = ((Vn/conv)-a1-a2/pfunk)*(Tr-theta)-(a4/pfunk), after Eq 11 in Shock and Helgeson 1988, rearranged to solve for a3.
#
# hexanoate
# ---------
# Input parameters:
# V=102.21, Cp=100, Gf=-80450, Hf=-139890, Saq=45.3, Z=-1, organic=True
#
# Published: 0.9427, 	Calculated: 0.943, 	omega*10**-5
# Published: 16.0700, 	Calculated: 16.0701, 	a1*10
# Published: 31.4589, 	Calculated: 31.4575, 	a2*10**-2
# Published: -6.6186, 	Calculated: -6.6141, 	a3
# Published: -4.0794, 	Calculated: -4.0795, 	a4*10**-4
# Published: 73.4573, 	Calculated: 73.46, 	c1
# Published: 17.3354, 	Calculated: 17.3354, 	c2*10**-4
#
# eta = 166027.0 angstroms*cal/mol, Y = -5.802e-05 1/K, Q = 5.903e-07 (1/bar), X = -3.09e-07 1/K**2
# abs_protonBorn = 0.5387 * 10**5 cal/mol, mentioned in text after Eq 47 in Shock and Helgeson 1988
# Gh is not provided, charge does not equal zero, and species is organic so estimate omega for ionic species from Shock and Helgeson 1990...
# BZ = 1.6291e+05 = ((-alphaZ*eta)/(Y*eta - 100)) - Z * abs_protonBorn, Eq 55 in Shock and Helgeson 1990
# omega = 94304 cal/mol = -1514.4*Saq + BZ, Eq 58 in Shock and Helgeson 1990
# Vs = -2.3291 cm3/mol = -omega*Q*conv, Eq 5 in Shock and Helgeson 1988, delta V solvation
# Vn cm3/mol = 104.54 cm3/mol = V - Vs, Eq 4 in Shock and Helgeson 1988, delta V nonsolvation
# Cps = -8.6881 cal/mol/K= omega*Tr*X, Eq 35 in Shock and Helgeson 1988, delta Cp solvation
# Cpn = 108.69 cal/mol/K = Cp - Cps, Eq 29 in Shock and Helgeson 1988, delta Cp nonsolvation
# Gh is unavailable and/or charge is not 0
# a1 = 1.607 cal/mol/bar = 1.3684E-2*Vn+0.1765, Eq 85 in Shock and Helgeson 1988
# sigma cm3/mol = 117.84 cm3/mol = 1.11*Vn + 1.8, Eq 87 in Shock and Helgeson 1988
# a2 = 3145.8 cal/mol = (sigma/conv-a1)*pfunk, Eq 8 in Shock and Helgeson 1988, rearranged to solve for a2
# a4 = -40795 (cal*K)/mol = -4.134*a2-27790, Eq 88 in Shock and Helgeson 1988
# c2 = 1.7335e+05 (cal*K)/mol = (0.2037*Cp - 3.0346)*10**-4, Eq 89 in Shock and Helgeson 1988
# c1 = 73.461 cal/mol/K = Cpn-((c2*(1/(Tr-theta))**2), Eq 31 in Shock and Helgeson 1988, rearranged to solve for c1
# a3 = -6.6141 (cal*K)/mol/bar = ((Vn/conv)-a1-a2/pfunk)*(Tr-theta)-(a4/pfunk), after Eq 11 in Shock and Helgeson 1988, rearranged to solve for a3.
#
# SELECT ITEMS FROM SHOCK AND HELGESON 1988, TABLE 12
# ---------------------------------------------
#
# Be+2
# ---------
# Input parameters:
# V=-25.4, Cp=-1.3, Gf=-83500, Hf=-91500, Saq=-55.7, Z=2, organic=False
#
# Published: 1.9007, 	Calculated: 1.9014, 	omega*10**-5
# Published: -1.0684, 	Calculated: -1.0681, 	a1*10
# Published: -10.3901, 	Calculated: -10.3895, 	a2*10**-2
# Published: 9.8338, 	Calculated: 9.8335, 	a3
# Published: -2.3495, 	Calculated: -2.3495, 	a4*10**-4
# Published: 22.9152, 	Calculated: 22.92, 	c1
# Published: -3.2994, 	Calculated: -3.2994, 	c2*10**-4
#
# eta = 166027.0 angstroms*cal/mol, Y = -5.802e-05 1/K, Q = 5.903e-07 (1/bar), X = -3.09e-07 1/K**2
# abs_protonBorn = 0.5387 * 10**5 cal/mol, mentioned in text after Eq 47 in Shock and Helgeson 1988
# Gh is not provided, charge does not equal zero, and species is inorganic so estimate omega for ionic species from Shock and Helgeson 1988...
# rej = 2.2294 = (Z**2 *(eta * Y - 100)/(Saq - alphaZ)), Eqs 46+56+57 in Shock and Helgeson 1988
# omega_abs_ion = 2.9788e+05 cal/mol = (eta*(charge**2))/rej, Eq 45 in Shock and Helgeson 1988
# omega = 1.9014e+05 cal/mol = omega_abs_ion-(Z*abs_protonBorn), Eq 47 in Shock and Helgeson 1988
# Vs = -4.696 cm3/mol = -omega*Q*conv, Eq 5 in Shock and Helgeson 1988, delta V solvation
# Vn cm3/mol = -20.704 cm3/mol = V - Vs, Eq 4 in Shock and Helgeson 1988, delta V nonsolvation
# Cps = -17.517 cal/mol/K= omega*Tr*X, Eq 35 in Shock and Helgeson 1988, delta Cp solvation
# Cpn = 16.217 cal/mol/K = Cp - Cps, Eq 29 in Shock and Helgeson 1988, delta Cp nonsolvation
# Gh is unavailable and/or charge is not 0
# a1 = -0.10681 cal/mol/bar = 1.3684E-2*Vn+0.1765, Eq 85 in Shock and Helgeson 1988
# sigma cm3/mol = -21.181 cm3/mol = 1.11*Vn + 1.8, Eq 87 in Shock and Helgeson 1988
# a2 = -1039 cal/mol = (sigma/conv-a1)*pfunk, Eq 8 in Shock and Helgeson 1988, rearranged to solve for a2
# a4 = -23495 (cal*K)/mol = -4.134*a2-27790, Eq 88 in Shock and Helgeson 1988
# c2 = -32994 (cal*K)/mol = (0.2037*Cp - 3.0346)*10**-4, Eq 89 in Shock and Helgeson 1988
# c1 = 22.922 cal/mol/K = Cpn-((c2*(1/(Tr-theta))**2), Eq 31 in Shock and Helgeson 1988, rearranged to solve for c1
# a3 = 9.8335 (cal*K)/mol/bar = ((Vn/conv)-a1-a2/pfunk)*(Tr-theta)-(a4/pfunk), after Eq 11 in Shock and Helgeson 1988, rearranged to solve for a3.
#
# S2O6-2
# ---------
# Input parameters:
# V=43.3, Cp=-46.5, Gf=--231000, Hf=-280400, Saq=30, Z=-2, organic=False
#
# Published: 2.7587, 	Calculated: 2.7584, 	omega*10**-5
# Published: 8.6225, 	Calculated: 8.6224, 	a1*10
# Published: 13.2724, 	Calculated: 13.2722, 	a2*10**-2
# Published: 0.5334, 	Calculated: 0.5335, 	a3
# Published: -3.3277, 	Calculated: -3.3277, 	a4*10**-4
# Published: 4.3301, 	Calculated: 4.33, 	c1
# Published: -12.5066, 	Calculated: -12.5067, 	c2*10**-4
#
# eta = 166027.0 angstroms*cal/mol, Y = -5.802e-05 1/K, Q = 5.903e-07 (1/bar), X = -3.09e-07 1/K**2
# abs_protonBorn = 0.5387 * 10**5 cal/mol, mentioned in text after Eq 47 in Shock and Helgeson 1988
# Gh is not provided, charge does not equal zero, and species is inorganic so estimate omega for ionic species from Shock and Helgeson 1988...
# rej = 3.9507 = (Z**2 *(eta * Y - 100)/(Saq - alphaZ)), Eqs 46+56+57 in Shock and Helgeson 1988
# omega_abs_ion = 1.681e+05 cal/mol = (eta*(charge**2))/rej, Eq 45 in Shock and Helgeson 1988
# omega = 2.7584e+05 cal/mol = omega_abs_ion-(Z*abs_protonBorn), Eq 47 in Shock and Helgeson 1988
# Vs = -6.8126 cm3/mol = -omega*Q*conv, Eq 5 in Shock and Helgeson 1988, delta V solvation
# Vn cm3/mol = 50.113 cm3/mol = V - Vs, Eq 4 in Shock and Helgeson 1988, delta V nonsolvation
# Cps = -25.412 cal/mol/K= omega*Tr*X, Eq 35 in Shock and Helgeson 1988, delta Cp solvation
# Cpn = -21.088 cal/mol/K = Cp - Cps, Eq 29 in Shock and Helgeson 1988, delta Cp nonsolvation
# Gh is unavailable and/or charge is not 0
# a1 = 0.86224 cal/mol/bar = 1.3684E-2*Vn+0.1765, Eq 85 in Shock and Helgeson 1988
# sigma cm3/mol = 57.425 cm3/mol = 1.11*Vn + 1.8, Eq 87 in Shock and Helgeson 1988
# a2 = 1327.2 cal/mol = (sigma/conv-a1)*pfunk, Eq 8 in Shock and Helgeson 1988, rearranged to solve for a2
# a4 = -33277 (cal*K)/mol = -4.134*a2-27790, Eq 88 in Shock and Helgeson 1988
# c2 = -1.2507e+05 (cal*K)/mol = (0.2037*Cp - 3.0346)*10**-4, Eq 89 in Shock and Helgeson 1988
# c1 = 4.3272 cal/mol/K = Cpn-((c2*(1/(Tr-theta))**2), Eq 31 in Shock and Helgeson 1988, rearranged to solve for c1
# a3 = 0.53349 (cal*K)/mol/bar = ((Vn/conv)-a1-a2/pfunk)*(Tr-theta)-(a4/pfunk), after Eq 11 in Shock and Helgeson 1988, rearranged to solve for a3.
#
# PLYASUNOV AND SHOCK 2001, TABLE 4
# ---------------------------------------------
#
# SO2
# ---------
# Input parameters:
# Gh=-0.51/4.184*1000, V=39.0, Cp=146/4.184, Z=0, organic=True
#
# Published: -0.95, 	Calculated: -0.95, 	omega*10**-5
# Published: 32.02, 	Calculated: 32.02, 	a1*10
# Published: 25.17, 	Calculated: 25.18, 	a2*10**-2
# Published: 18.71, 	Calculated: 18.66, 	a3
# Published: -10.79, 	Calculated: -10.79, 	a4*10**-4
# Published: 93.2, 	Calculated: 94.7, 	c1
# Published: 20.97, 	Calculated: 20.97, 	c2*10**-4
#
# eta = 166027.0 angstroms*cal/mol, Y = -5.802e-05 1/K, Q = 5.903e-07 (1/bar), X = -3.09e-07 1/K**2
# abs_protonBorn = 0.5387 * 10**5 cal/mol, mentioned in text after Eq 47 in Shock and Helgeson 1988
# Gh is provided and charge equals zero so estimate omega from Plyasunov and Shock 2001...
# omega = -94724 J/mol = (2.61+(324.1/(Gh-90.6)))/10**-5, Eq 8 in Plyasunov and Shock 2001
# Vs = 0.55915 cm3/mol = -omega*Q*conv, Eq 5 in Shock and Helgeson 1988, delta V solvation
# Vn cm3/mol = 38.441 cm3/mol = V - Vs, Eq 4 in Shock and Helgeson 1988, delta V nonsolvation
# Cps = 2.0857 cal/mol/K= omega*Tr*X, Eq 35 in Shock and Helgeson 1988, delta Cp solvation
# Cpn = 32.809 cal/mol/K = Cp - Cps, Eq 29 in Shock and Helgeson 1988, delta Cp nonsolvation
# Gh is provided and charge is neutral, so estimate a1, a2, and a4 from Plysunov and Shock 2001
# estimation of sigma is not required using this method from Plyasunov and Shock 2001...
# a1 = 3.2017 J/mol/bar = ((0.820-(1.858*10**-3*Gh))*V)/10, Eq 10 in Plyasunov and Shock 2001
# a2 = 2517.6 J/mol = ((0.648+((0.00481)*(Gh)))*V)/1E-2, Eq 11 in Plyasunov and Shock 2001
# a4 = -1.0793e+05 (J*K)/mol = (8.10-(0.746*a2*1E-2)+(0.219*Gh))/1E-4, Eq 12 in Plyasunov and Shock 2001
# c2 = 2.0967e+05 (J*K)/mol = 21.4+(0.849*Gh), Eq 14 in Plyasunov and Shock 2001
# c1 = 22.626 cal/mol/K = Cpn-((c2*(1/(Tr-theta))**2), Eq 31 in Shock and Helgeson 1988, rearranged to solve for c1
# a3 = 4.4606 (cal*K)/mol/bar = ((Vn/conv)-a1-a2/pfunk)*(Tr-theta)-(a4/pfunk), after Eq 11 in Shock and Helgeson 1988, rearranged to solve for a3.
#
# Pyridine
# ---------
# Input parameters:
# Gh=-11.7/4.184*1000, V=77.1, Cp=306/4.184, Z=0, organic=True
#
# Published: -0.56, 	Calculated: -0.56, 	omega*10**-5
# Published: 64.89, 	Calculated: 64.9, 	a1*10
# Published: 45.62, 	Calculated: 45.62, 	a2*10**-2
# Published: 69.94, 	Calculated: 16.68, 	a3
# Published: -28.50, 	Calculated: -28.5, 	a4*10**-4
# Published: 278.1, 	Calculated: 277.6, 	c1
# Published: 11.47, 	Calculated: 11.47, 	c2*10**-4
#
# eta = 166027.0 angstroms*cal/mol, Y = -5.802e-05 1/K, Q = 5.903e-07 (1/bar), X = -3.09e-07 1/K**2
# abs_protonBorn = 0.5387 * 10**5 cal/mol, mentioned in text after Eq 47 in Shock and Helgeson 1988
# Gh is provided and charge equals zero so estimate omega from Plyasunov and Shock 2001...
# omega = -55813 J/mol = (2.61+(324.1/(Gh-90.6)))/10**-5, Eq 8 in Plyasunov and Shock 2001
# Vs = 0.32946 cm3/mol = -omega*Q*conv, Eq 5 in Shock and Helgeson 1988, delta V solvation
# Vn cm3/mol = 76.771 cm3/mol = V - Vs, Eq 4 in Shock and Helgeson 1988, delta V nonsolvation
# Cps = 1.229 cal/mol/K= omega*Tr*X, Eq 35 in Shock and Helgeson 1988, delta Cp solvation
# Cpn = 71.907 cal/mol/K = Cp - Cps, Eq 29 in Shock and Helgeson 1988, delta Cp nonsolvation
# Gh is provided and charge is neutral, so estimate a1, a2, and a4 from Plysunov and Shock 2001
# estimation of sigma is not required using this method from Plyasunov and Shock 2001...
# a1 = 6.4898 J/mol/bar = ((0.820-(1.858*10**-3*Gh))*V)/10, Eq 10 in Plyasunov and Shock 2001
# a2 = 4562.2 J/mol = ((0.648+((0.00481)*(Gh)))*V)/1E-2, Eq 11 in Plyasunov and Shock 2001
# a4 = -2.8496e+05 (J*K)/mol = (8.10-(0.746*a2*1E-2)+(0.219*Gh))/1E-4, Eq 12 in Plyasunov and Shock 2001
# c2 = 1.1467e+05 (J*K)/mol = 21.4+(0.849*Gh), Eq 14 in Plyasunov and Shock 2001
# c1 = 66.338 cal/mol/K = Cpn-((c2*(1/(Tr-theta))**2), Eq 31 in Shock and Helgeson 1988, rearranged to solve for c1
# a3 = 16.685 (cal*K)/mol/bar = ((Vn/conv)-a1-a2/pfunk)*(Tr-theta)-(a4/pfunk), after Eq 11 in Shock and Helgeson 1988, rearranged to solve for a3.
#
# 1,4-Butanediol
# ---------
# Input parameters:
# Gh=-37.7/4.184*1000, V=88.23, Cp=347/4.184, Z=0, organic=True
#
# Published: 0.08, 	Calculated: 0.08, 	omega*10**-5
# Published: 78.50, 	Calculated: 78.53, 	a1*10
# Published: 41.17, 	Calculated: 41.17, 	a2*10**-2
# Published: 76.32, 	Calculated: 76.06, 	a3
# Published: -30.87, 	Calculated: -30.87, 	a4*10**-4
# Published: 369.2, 	Calculated: 369.3, 	c1
# Published: -10.61, 	Calculated: -10.61, 	c2*10**-4
#
# eta = 166027.0 angstroms*cal/mol, Y = -5.802e-05 1/K, Q = 5.903e-07 (1/bar), X = -3.09e-07 1/K**2
# abs_protonBorn = 0.5387 * 10**5 cal/mol, mentioned in text after Eq 47 in Shock and Helgeson 1988
# Gh is provided and charge equals zero so estimate omega from Plyasunov and Shock 2001...
# omega = 8388.9 J/mol = (2.61+(324.1/(Gh-90.6)))/10**-5, Eq 8 in Plyasunov and Shock 2001
# Vs = -0.049519 cm3/mol = -omega*Q*conv, Eq 5 in Shock and Helgeson 1988, delta V solvation
# Vn cm3/mol = 88.28 cm3/mol = V - Vs, Eq 4 in Shock and Helgeson 1988, delta V nonsolvation
# Cps = -0.18472 cal/mol/K= omega*Tr*X, Eq 35 in Shock and Helgeson 1988, delta Cp solvation
# Cpn = 83.12 cal/mol/K = Cp - Cps, Eq 29 in Shock and Helgeson 1988, delta Cp nonsolvation
# Gh is provided and charge is neutral, so estimate a1, a2, and a4 from Plysunov and Shock 2001
# estimation of sigma is not required using this method from Plyasunov and Shock 2001...
# a1 = 7.8529 J/mol/bar = ((0.820-(1.858*10**-3*Gh))*V)/10, Eq 10 in Plyasunov and Shock 2001
# a2 = 4117.4 J/mol = ((0.648+((0.00481)*(Gh)))*V)/1E-2, Eq 11 in Plyasunov and Shock 2001
# a4 = -3.0872e+05 (J*K)/mol = (8.10-(0.746*a2*1E-2)+(0.219*Gh))/1E-4, Eq 12 in Plyasunov and Shock 2001
# c2 = -1.0607e+05 (J*K)/mol = 21.4+(0.849*Gh), Eq 14 in Plyasunov and Shock 2001
# c1 = 88.271 cal/mol/K = Cpn-((c2*(1/(Tr-theta))**2), Eq 31 in Shock and Helgeson 1988, rearranged to solve for c1
# a3 = 18.178 (cal*K)/mol/bar = ((Vn/conv)-a1-a2/pfunk)*(Tr-theta)-(a4/pfunk), after Eq 11 in Shock and Helgeson 1988, rearranged to solve for a3.
#
# beta-alanine
# ---------
# Input parameters:
# Gh=-74/4.184*1000, V=58.7, Cp=76/4.184, Z=0, organic=True
#
# Published: 0.64, 	Calculated: 0.64, 	omega*10**-5
# Published: 56.17, 	Calculated: 56.2, 	a1*10
# Published: 17.14, 	Calculated: 17.14, 	a2*10**-2
# Published: 54.55, 	Calculated: 54.26, 	a3
# Published: -20.90, 	Calculated: -20.9, 	a4*10**-4
# Published: 165.5, 	Calculated: 166.1, 	c1
# Published: -41.43, 	Calculated: -41.43, 	c2*10**-4
#
# eta = 166027.0 angstroms*cal/mol, Y = -5.802e-05 1/K, Q = 5.903e-07 (1/bar), X = -3.09e-07 1/K**2
# abs_protonBorn = 0.5387 * 10**5 cal/mol, mentioned in text after Eq 47 in Shock and Helgeson 1988
# Gh is provided and charge equals zero so estimate omega from Plyasunov and Shock 2001...
# omega = 64098 J/mol = (2.61+(324.1/(Gh-90.6)))/10**-5, Eq 8 in Plyasunov and Shock 2001
# Vs = -0.37837 cm3/mol = -omega*Q*conv, Eq 5 in Shock and Helgeson 1988, delta V solvation
# Vn cm3/mol = 59.078 cm3/mol = V - Vs, Eq 4 in Shock and Helgeson 1988, delta V nonsolvation
# Cps = -1.4114 cal/mol/K= omega*Tr*X, Eq 35 in Shock and Helgeson 1988, delta Cp solvation
# Cpn = 19.576 cal/mol/K = Cp - Cps, Eq 29 in Shock and Helgeson 1988, delta Cp nonsolvation
# Gh is provided and charge is neutral, so estimate a1, a2, and a4 from Plysunov and Shock 2001
# estimation of sigma is not required using this method from Plyasunov and Shock 2001...
# a1 = 5.6205 J/mol/bar = ((0.820-(1.858*10**-3*Gh))*V)/10, Eq 10 in Plyasunov and Shock 2001
# a2 = 1714.4 J/mol = ((0.648+((0.00481)*(Gh)))*V)/1E-2, Eq 11 in Plyasunov and Shock 2001
# a4 = -2.0895e+05 (J*K)/mol = (8.10-(0.746*a2*1E-2)+(0.219*Gh))/1E-4, Eq 12 in Plyasunov and Shock 2001
# c2 = -4.1426e+05 (J*K)/mol = 21.4+(0.849*Gh), Eq 14 in Plyasunov and Shock 2001
# c1 = 39.696 cal/mol/K = Cpn-((c2*(1/(Tr-theta))**2), Eq 31 in Shock and Helgeson 1988, rearranged to solve for c1
# a3 = 12.969 (cal*K)/mol/bar = ((Vn/conv)-a1-a2/pfunk)*(Tr-theta)-(a4/pfunk), after Eq 11 in Shock and Helgeson 1988, rearranged to solve for a3.

# %% [markdown]
# ### Importing estimated HKF parameters into the database for calculations
#
# What next? If hexanoic acid was actually absent from the WORM database then we might follow this procedure to get hexanoic acid to show up in our modeling calculations:
# 1. download a copy of the [WORM database CSV file](https://github.com/worm-portal/WORM-db/blob/master/wrm_data.csv)
# 2. add a new line for "hexanoic-acid" (be sure to replace spaces with dashes in chemical species names, and don't use a name that is already in the database)
# 3. fill out the columns for "hexanoic-acid" while referencing [the WORM database documentation](https://worm-portal.asu.edu/docs/database/)
#    - the "omega" HKF parameter goes in the "omega.lambda" column, the "a1" parameter goes in the "a1.a" column, etc.
#    - if you only need this database for a pyCHNOSZ calculation, you can ignore all of the columns to the right of "z.T".
#    - if you need this database for a speciation calculation with AqEquil, you need to fill out all of the columns in the CSV. The exception is the "dissrxn" column which you can leave blank if you'd prefer the chemical species' dissociation reaction to be generated automatically for you.
# 4. import your CSV into your tool of choice.
#
# For example, importing a custom CSV database into pyCHNOSZ can be done with:
#
# ```
# from pyCHNOSZ import *
# _ = thermo("WORM")
# _ = add_OBIGT("my_custom_database.csv")
#
# # ... your calculation goes here, e.g., using subcrt()
# ```
#
# Importing a custom database into AqEquil can be done with:
# ```
# import AqEquil
# ae = AqEquil.AqEquil(db="my_custom_database.csv")
#
# # ... your speciation calculation goes here, e.g., using ae.speciate()
# ```
#
# Working with thermodynamic databases can be tricky to get right the first time. If you reach a point where you get stuck and need clarification to proceed, feel free to reach out to the WORM administrator Grayson Boyer (email: gmboyer at asu dot edu) and ask to join the WORM Slack community where these kinds of questions get answered.

# %% [markdown]
# End of demo.
