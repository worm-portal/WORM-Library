# %% [markdown]
# <left>
# <table style="margin-top:0px; margin-left:0px;">
# <tr>
#   <td><img src="https://raw.githubusercontent.com/worm-portal/WORM-Figures/master/style/worm.png" alt="WORM" title="WORM" width=50/></td>
#   <td><h1 style=font-size:30px>Aqueous Organic Estimator (AqOrg) feature demo</h1><br />
# </tr>
# </table>
# </left>

# %%
from aqorg import Estimate

# %% [markdown]
# ### Single compound estimation

# %% [markdown]
# You can estimate the properties of a neutral organic molecule from its name alone. AqOrg will search the online PubChem database for a match and then attempt to estimate its properties using group additivity theory. Some functional groups are not yet supported.

# %%
pentanol = Estimate("pentanol")

# %% [markdown]
# Look up the molecule's OBIGT table of estimated values.

# %%
pentanol.OBIGT
# Out:
#        name   abbrv formula state   ref1    ref2                 date model  \
# 0  pentanol  C5H12O  C5H12O    aq  AqOrg  GrpAdd  20/04/2026 12:54:45   HKF
#
#   E_units         G  ...          Cp       V      a1.a       a2.b        a3.c  \
# 0       J -156580.0  ...  528.305433  102.11  85.81333  60.774463  100.429833
#
#         a4.d        c1.e      c2.f  omega.lambda  z.T
# 0 -39.642369  498.412926  12.07798     -0.580589    0
#
# [1 rows x 22 columns]

# %% [markdown]
# Look up individual parameters.

# %%
pentanol.Cph, pentanol.omega, pentanol.Sh, pentanol.Sh_err
# Out:
# (395.0, -0.5805886985627096, -179.67466040583602, 0)

# %% [markdown]
# Look up how groups were summed to estimate a property.

# %%
pentanol.hyd_group_contributions
# Out:
#               group count     Gh  Gh_contribution     Hh  Hh_contribution  \
# 0  [C!H3]-[CX4H3R0]     1   3.72             3.72  -8.19            -8.19
# 1     C-[CX4H2R0]-C     3   0.68             2.04  -3.52           -10.56
# 2       O-[CX4H2]-C     1   0.77             0.77  -5.17            -5.17
# 3          C-[OX2H]     1 -25.46           -25.46 -38.34           -38.34
# 4                Yo         7.95             7.95  -2.29            -2.29
# 5             Total                        -10.98                  -64.55
#
#      Cph  Cph_contribution      V  V_contribution
# 0  132.0             132.0  25.56           25.56
# 1   62.0             186.0  15.61           46.83
# 2   68.0              68.0  17.25           17.25
# 3    9.0               9.0  11.35           11.35
# 4    0.0               0.0   1.12            1.12
# 5                    395.0                 102.11

# %% [markdown]
# Specify known values for properties and parameters. See which ones can be defined with `help(AqOrg.Estimate)`. Do not show a picture of the molecule with `show=False`.

# %%
pentanol = Estimate("pentanol", Gh=-11.11, Hig=-294.56, Cpaq=535, show=False)
pentanol.OBIGT
# Out:
#        name   abbrv formula state   ref1    ref2                 date model  \
# 0  pentanol  C5H12O  C5H12O    aq  AqOrg  GrpAdd  20/04/2026 12:54:49   HKF
#
#   E_units         G  ...          Cp       V       a1.a       a2.b  \
# 0       J -156710.0  ...  528.305433  102.11  85.837993  60.710613
#
#          a3.c       a4.d        c1.e      c2.f  omega.lambda  z.T
# 0  100.372238 -39.623208  498.674779  11.96761     -0.576511    0
#
# [1 rows x 22 columns]

# %% [markdown]
# Perform simple group matching with `test=True`. First it will show ideal gas group matching followed by hydration group matching. Ideal gas and hydration properties for the molecule are summed into aqueous properties.

# %%
Estimate("pentanol", test=True, show=False)
# Out:
# Ideal gas atom group matches:
#   Atom   Symbol   SMARTS group
#   ----   ------   ------------
#   0      C        [!R;CX4H3]
#   1      C        [!R;CX4H2]
#   2      C        [!R;CX4H2]
#   3      C        [!R;CX4H2]
#   4      C        [!R;CX4H2]
#   5      O        [OX2H;!$([OX2H]-[#6]=[O]);!$([OX2H]-a)]
#
# Group counts:
#   SMARTS group                             Count
#   ------------                             -----
#   [!R;CX4H3]                               1
#   [!R;CX4H2]                               4
#   [OX2H;!$([OX2H]-[#6]=[O]);!$([OX2H]-a)]  1
# Hydration atom group matches:
#   Atom   Symbol   SMARTS group
#   ----   ------   ------------
#   0      C        [C!H3]-[CX4H3R0]
#   1      C        C-[CX4H2R0]-C
#   2      C        C-[CX4H2R0]-C
#   3      C        C-[CX4H2R0]-C
#   4      C        O-[CX4H2]-C
#   5      O        C-[OX2H]
#
# Group counts:
#   SMARTS group                             Count
#   ------------                             -----
#   [C!H3]-[CX4H3R0]                         1
#   C-[CX4H2R0]-C                            3
#   O-[CX4H2]-C                              1
#   C-[OX2H]                                 1

# %% [markdown]
# ### Multi-compound estimation

# %%
import pandas as pd
mols = ["pentanol", "hexanol", "heptanol"]
OBIGT = pd.DataFrame()
for mol in mols:
    OBIGT = pd.concat([OBIGT, Estimate(mol, show=False).OBIGT], ignore_index=True)
OBIGT
# Out:
#        name   abbrv formula state   ref1    ref2                 date model  \
# 0  pentanol  C5H12O  C5H12O    aq  AqOrg  GrpAdd  20/04/2026 12:54:52   HKF
# 1   hexanol  C6H14O  C6H14O    aq  AqOrg  GrpAdd  20/04/2026 12:54:53   HKF
# 2  heptanol  C7H16O  C7H16O    aq  AqOrg  GrpAdd  20/04/2026 12:54:54   HKF
#
#   E_units         G  ...          Cp       V        a1.a       a2.b  \
# 0       J -156580.0  ...  528.305433  102.11   85.813330  60.774463
# 1       J -147480.0  ...  613.200273  117.72   98.783255  70.450358
# 2       J -138380.0  ...  698.095114  133.33  111.713735  80.228368
#
#          a3.c       a4.d        c1.e      c2.f  omega.lambda  z.T
# 0  100.429833 -39.642369  498.412926  12.07798     -0.580589    0
# 1  119.945631 -46.711667  581.936497  12.65530     -0.602091    0
# 2  139.754396 -53.857142  665.457379  13.23262     -0.623885    0
#
# [3 rows x 22 columns]

# %% [markdown]
# ### Load a custom table of group contribution values
#
# AqOrg has a built-in table of group contribution values. If you want to replace it with your own custom table, specify the filename of your CSV table in ```group_data```. In this example, custom_groups.csv is no different than the default database so you should not expect the estimated values to be any different than before.

# %%
pentanol = Estimate("pentanol", group_data="custom_groups.csv", show=False)
pentanol.OBIGT
# Out:
#        name   abbrv formula state   ref1    ref2                 date model  \
# 0  pentanol  C5H12O  C5H12O    aq  AqOrg  GrpAdd  20/04/2026 12:54:55   HKF
#
#   E_units         G  ...          Cp       V      a1.a       a2.b        a3.c  \
# 0       J -156580.0  ...  528.305433  102.11  85.81333  60.774463  100.429833
#
#         a4.d        c1.e      c2.f  omega.lambda  z.T
# 0 -39.642369  498.412926  12.07798     -0.580589    0
#
# [1 rows x 22 columns]

# %% [markdown]
# End of demo.
