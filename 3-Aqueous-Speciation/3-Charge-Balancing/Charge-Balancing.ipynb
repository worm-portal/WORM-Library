# %% [markdown]
# <left>
# <table style="margin-top:0px; margin-left:0px;">
# <tr>
#   <td><img src="https://gitlab.com/worm1/worm-figures/-/raw/master/style/worm.png" alt="WORM" title="WORM" width=50/></td>
#   <td><h1 style=font-size:30px>Charge Balancing</h1><br />
# </tr>
# </table>
# <\left>

# %% [markdown]
# By default, no charge balancing is performed and electrical imbalance is included in the speciation report. Alternatively, it is possible to balance charge on a chosen ion by including the following parameter in the speciate() function:
#
# ```python
# charge_balance_on='H+', # species used for balance goes here
# ```
#
# This allows the activity of the chosen species to shift to bring the total charge imbalance to 0 in each sample.
#
# The sample input file used in this example, peru.csv, contains data from hot spring samples collected from the Peruvian Andes ([Newell & Scott 2020](https://doi.org/10.26022/IEDA/111569))

# %%
import AqEquil
ae = AqEquil.AqEquil()

# %%
# perform a speciation calculation with the default WORM database 'wrm'
speciation = ae.speciate(input_filename="peru.csv",
                         exclude=["Year", "Area"],
                         delete_generated_folders=True,
                         charge_balance_on='H+')
# Out:
# Warning: no 'logfO2' column found. Attempting to find a column for aqueous O2 to estimate logfO2 at sample temperature and pressure...
#
# Using wrm to speciate DNCB17-21
# Using wrm to speciate DN13CB06
# Using wrm to speciate DNCB17-36
# Using wrm to speciate DNCB17-37
# Using wrm to speciate DN13CB14
# Using wrm to speciate DNCB15-07
# Using wrm to speciate DNCB15-10
# Using wrm to speciate DNCB17-7b
# Using wrm to speciate DN13CB11
# Using wrm to speciate DNCB17-24
# Using wrm to speciate DN13CB07
# Using wrm to speciate DN13CB04
# Using wrm to speciate DNCB17-06
# Using wrm to speciate DN17CB-01
# Using wrm to speciate DNCB17-30
# Using wrm to speciate DNCB17-09
# Using wrm to speciate DN13CB08b
# Using wrm to speciate DNCB15-9b
# Using wrm to speciate DN13CB13
# Using wrm to speciate DNCB15-13
# Using wrm to speciate DNCB17-25
# Using wrm to speciate DN13CB05
# Using wrm to speciate DNCB17-13
# Using wrm to speciate DNCB17-02
# Using wrm to speciate DNCB15-09
# Using wrm to speciate DNCB17-38
# Using wrm to speciate DN13CB09
# Using wrm to speciate DNCB15-12
# Using wrm to speciate DNCB15-08
# Using wrm to speciate DNCB17-32
# Using wrm to speciate DNCB17-7a
# Using wrm to speciate DNCB15-11
# Finished!

# %% [markdown]
# ### Confirm charge balance

# %%
speciation.lookup(['sigma(mz) cations', 'sigma(mz) anions', 'charge imbalance % of total charge'])
# Out:
# Sample    charge imbalance % of total charge sigma(mz) anions  \
#                                    eq/kg.H2O        eq/kg.H2O
# DN13CB11                                 0.0    -5.556789e-02
# DN13CB14                                 0.0    -1.982166e-02
# DNCB15-07                               -0.0    -4.125997e-02
# DNCB15-08                                0.0    -6.699503e-02
# DNCB15-09                                0.0    -3.970794e-07
# DNCB15-9b                                0.0    -7.930387e-03
# DNCB15-10                                0.0    -2.706073e-02
# DN13CB04                                 0.0    -7.399389e-08
# DN13CB05                                 0.0    -2.399417e-01
# DN13CB06                                 0.0    -2.231271e-01
# DN13CB07                                 0.0    -6.263356e-03
# DN13CB08b                                0.0    -5.579698e-02
# DN13CB09                                 0.0    -6.150649e-02
# DN13CB13                                 0.0    -1.266481e-02
# DNCB15-12                                0.0    -4.938313e-02
# DNCB15-13                                0.0    -1.709469e-01
# DNCB15-11                                0.0    -2.181376e-03
# DN17CB-01                                0.0    -3.979584e-03
# DNCB17-02                                0.0    -3.981224e-03
# DNCB17-06                               -0.0    -5.426031e-03
# DNCB17-7a                                0.0    -1.421214e-03
# DNCB17-7b                                0.0    -1.418242e-03
# DNCB17-09                                0.0    -1.708362e-03
# DNCB17-13                                0.0    -3.220199e-02
# DNCB17-21                                0.0    -1.438530e-02
# DNCB17-24                                0.0    -2.100267e-03
# DNCB17-25                                0.0    -1.239537e-02
# DNCB17-30                                0.0    -1.301137e-02
# DNCB17-32                                0.0    -8.021225e-03
# DNCB17-36                                0.0    -3.197980e-03
# DNCB17-37                                0.0    -5.029775e-03
# DNCB17-38                                0.0    -6.914755e-03
#
# Sample    sigma(mz) cations
#                   eq/kg.H2O
# DN13CB11       5.556789e-02
# DN13CB14       1.982166e-02
# DNCB15-07      4.125997e-02
# DNCB15-08      6.699503e-02
# DNCB15-09      3.970794e-07
# DNCB15-9b      7.930387e-03
# DNCB15-10      2.706073e-02
# DN13CB04       7.399389e-08
# DN13CB05       2.399417e-01
# DN13CB06       2.231271e-01
# DN13CB07       6.263356e-03
# DN13CB08b      5.579698e-02
# DN13CB09       6.150649e-02
# DN13CB13       1.266481e-02
# DNCB15-12      4.938313e-02
# DNCB15-13      1.709469e-01
# DNCB15-11      2.181376e-03
# DN17CB-01      3.979584e-03
# DNCB17-02      3.981224e-03
# DNCB17-06      5.426031e-03
# DNCB17-7a      1.421214e-03
# DNCB17-7b      1.418242e-03
# DNCB17-09      1.708362e-03
# DNCB17-13      3.220199e-02
# DNCB17-21      1.438530e-02
# DNCB17-24      2.100267e-03
# DNCB17-25      1.239537e-02
# DNCB17-30      1.301137e-02
# DNCB17-32      8.021225e-03
# DNCB17-36      3.197980e-03
# DNCB17-37      5.029775e-03
# DNCB17-38      6.914755e-03

# %% [markdown]
# ### Comparing unbalanced (input) and balanced speciations
#
# It is possible to compare charge-balanced and non-charge-balanced speciation results. For pH, this can be done easily by comparing pH_(input) to pH, where the latter is has been adjusted for charge balance:

# %%
speciation.barplot(["pH_(input)", "pH"], plot_width=7)

# %% [markdown]
# When balancing on other chemical species, plotting might get tricky. This is because plots don't accept variables with different units on the y-axis. For instance, if you balance on Na$^+$, the speciation will return a log activity of Na$^+$, while you might've entered Na$^+$ in your sample spreadsheet as molality or ppm. These cannot be plotted alongside each other because they have different units.
#
# One solution is to run two speciations, one unbalanced and one balanced on Na$^+$, and then compare the speciated log activities of Na$^+$.

# %%
# unbalanced speciation
unbalanced_speciation = ae.speciate(input_filename="peru.csv",
                         exclude=["Year", "Area"],
                         delete_generated_folders=True)

# speciation balanced on Na+
balanced_speciation = ae.speciate(input_filename="peru.csv",
                         exclude=["Year", "Area"],
                         delete_generated_folders=True,
                         charge_balance_on='Na+')
# Out:
# Warning: no 'logfO2' column found. Attempting to find a column for aqueous O2 to estimate logfO2 at sample temperature and pressure...
#
# Using wrm to speciate DNCB17-21
# Using wrm to speciate DN13CB06
# Using wrm to speciate DNCB17-36
# Using wrm to speciate DNCB17-37
# Using wrm to speciate DN13CB14
# Using wrm to speciate DNCB15-07
# Using wrm to speciate DNCB15-10
# Using wrm to speciate DNCB17-7b
# Using wrm to speciate DN13CB11
# Using wrm to speciate DNCB17-24
# Using wrm to speciate DN13CB07
# Using wrm to speciate DN13CB04
# Using wrm to speciate DNCB17-06
# Using wrm to speciate DN17CB-01
# Using wrm to speciate DNCB17-30
# Using wrm to speciate DNCB17-09
# Using wrm to speciate DN13CB08b
# Using wrm to speciate DNCB15-9b
# Using wrm to speciate DN13CB13
# Using wrm to speciate DNCB15-13
# Using wrm to speciate DNCB17-25
# Using wrm to speciate DN13CB05
# Using wrm to speciate DNCB17-13
# Using wrm to speciate DNCB17-02
# Using wrm to speciate DNCB15-09
# Using wrm to speciate DNCB17-38
# Using wrm to speciate DN13CB09
# Using wrm to speciate DNCB15-12
# Using wrm to speciate DNCB15-08
# Using wrm to speciate DNCB17-32
# Using wrm to speciate DNCB17-7a
# Using wrm to speciate DNCB15-11
# Finished!
# Warning: no 'logfO2' column found. Attempting to find a column for aqueous O2 to estimate logfO2 at sample temperature and pressure...
#
# Using wrm to speciate DNCB17-21
# Using wrm to speciate DN13CB06
# Using wrm to speciate DNCB17-36
# Using wrm to speciate DNCB17-37
# Using wrm to speciate DN13CB14
# Using wrm to speciate DNCB15-07
# Error: EQ3 failed to produce a pickup file for DNCB15.07.3i
# Using wrm to speciate DNCB15-10
# Using wrm to speciate DNCB17-7b
# Using wrm to speciate DN13CB11
# Using wrm to speciate DNCB17-24
# Using wrm to speciate DN13CB07
# Error: EQ3 failed to produce a pickup file for DN13CB07.3i
# Using wrm to speciate DN13CB04
# Error: EQ3 failed to produce a pickup file for DN13CB04.3i
# Using wrm to speciate DNCB17-06
# Using wrm to speciate DN17CB-01
# Using wrm to speciate DNCB17-30
# Using wrm to speciate DNCB17-09
# Using wrm to speciate DN13CB08b
# Using wrm to speciate DNCB15-9b
# Error: EQ3 failed to produce a pickup file for DNCB15.9b.3i
# Using wrm to speciate DN13CB13
# Using wrm to speciate DNCB15-13
# Using wrm to speciate DNCB17-25
# Using wrm to speciate DN13CB05
# Using wrm to speciate DNCB17-13
# Using wrm to speciate DNCB17-02
# Using wrm to speciate DNCB15-09
# Error: EQ3 failed to produce a pickup file for DNCB15.09.3i
# Using wrm to speciate DNCB17-38
# Error: EQ3 failed to produce a pickup file for DNCB17.38.3i
# Using wrm to speciate DN13CB09
# Using wrm to speciate DNCB15-12
# Using wrm to speciate DNCB15-08
# Using wrm to speciate DNCB17-32
# Using wrm to speciate DNCB17-7a
# Using wrm to speciate DNCB15-11
#
# Sample DNCB15-07 experienced errors during speciation:
#
# * Error - (EQ3NR/eq3nr) Hybrid Newton-Raphson iteration failed after 20 iterations because the code detected that iteration was diverging.
#
#
# Sample DNCB15-09 experienced errors during speciation:
#
# * Error - (EQ3NR/eq3nr) Hybrid Newton-Raphson iteration failed after 20 iterations because the code detected that iteration was diverging.
#
#
# Sample DNCB15-9b experienced errors during speciation:
#
# * Error - (EQ3NR/eq3nr) Hybrid Newton-Raphson iteration failed after 20 iterations because the code detected that iteration was diverging.
#
#
# Sample DN13CB04 experienced errors during speciation:
#
# * Error - (EQ3NR/eq3nr) Hybrid Newton-Raphson iteration failed after 11 iterations because the code detected that iteration was diverging.
#
#
# Sample DN13CB07 experienced errors during speciation:
#
# * Error - (EQ3NR/eq3nr) Hybrid Newton-Raphson iteration failed after 12 iterations because the code detected that iteration was diverging.
#
#
# Sample DNCB17-38 experienced errors during speciation:
#
# * Error - (EQ3NR/eq3nr) Hybrid Newton-Raphson iteration failed after 12 iterations because the code detected that iteration was diverging.
#
# Finished!

# %%
# This cell takes the balanced and unbalanced
# speciation reports and joins them side-by-side.
# Column names from the unbalanced report end in '_(unbalanced)'
# Column names from the balanced report end in '_(balanced)'

import pandas as pd
import copy

excluded_cols = [("Year", ""), ("Area", "")] # metadata headers and subheaders
necessary_cols = [("pH", "pH"), ("Temperature", "degC")]

input_cols = excluded_cols+necessary_cols+[col for col in unbalanced_speciation.report if "_(input)" in str(col)]
input_df = unbalanced_speciation.report[input_cols]
output_cols_unbalanced = [col for col in unbalanced_speciation.report.columns if col not in input_cols]
output_df_unbalanced = unbalanced_speciation.report[output_cols_unbalanced]
output_df_unbalanced.columns = [(col[0]+"_(unbalanced)", col[1]) for col in output_cols_unbalanced]
output_cols_balanced = [col for col in balanced_speciation.report.columns if col not in input_cols]
output_df_balanced = balanced_speciation.report[output_cols_balanced]
output_df_balanced.columns = [(col[0]+"_(balanced)", col[1]) for col in output_cols_balanced]
output_df_all = pd.concat([input_df, output_df_unbalanced, output_df_balanced], axis=1)
cbal_comparison = copy.deepcopy(unbalanced_speciation)
cbal_comparison.report = output_df_all

# %%
# compare samples before and after balancing on Na+. Display only the first five rows with .head()
cbal_comparison.lookup(["Na+_(unbalanced)", "Na+_(balanced)"]).head()
# Out:
# Sample    Na+_(unbalanced) Na+_(balanced)
#               log_activity   log_activity
# DN13CB11           -1.4031        -1.4900
# DN13CB14           -1.8000        -1.9547
# DNCB15-07              NaN            NaN
# DNCB15-08          -1.3652        -1.3626
# DNCB15-09              NaN            NaN

# %%
# using a barplot to compare samples before and after balancing on Na+
cbal_comparison.barplot(['Na+_(unbalanced)', 'Na+_(balanced)'], plot_width=7, show_missing=True)
