# %% [markdown]
# <left>
# <table style="margin-top:0px; margin-left:0px;">
# <tr>
#   <td><img src="https://raw.githubusercontent.com/worm-portal/WORM-Figures/master/style/worm.png" alt="WORM" title="WORM" width=50/></td>
#   <td><h1 style=font-size:30px>Custom data0 example</h1><br />
# </tr>
# </table>
# </left>

# %% [markdown]
# This demo is for users who want to create a custom data0 file.
#
# In this example, the thermodynamic databases `thermodata.csv` and `solid_solutions.csv` will be recalibrated with the `create_data0` function to create a data0 file that is applicable from 0 to 350 degrees C, all at 200 bars. This will actually create a new database (called a data0 file) with the desired temperature range and pressures. We can pick a three-letter code to designate this recalibrated data0 file; in this case we'll use 'cst', short for 'custom'.
#
# Once the 'cst' data0 database is created, it can be used in a speciation calculation with the `speciate` function to speciate samples at 200 bars.

# %%
import aqequil
ae = aqequil.AqEquil(db="thermodata.csv")
# Out:
# Loading a user-supplied thermodynamic database...
# thermodata.csv is now set as the active thermodynamic database.
# Element database elements.csv is active.
# Loading thermodynamic database into pyCHNOSZ...

# %%
# creating a new database called data0.cst from thermodata.csv
# and solid_solutions.csv from 0 to 350 degrees C and 200 bars.
ae.create_data0(
    grid_temps=[0.01, 50.0, 100.0, 150.0, 200.0, 250.0, 300.0, 350.0],
    grid_press=[200, 200, 200, 200, 200, 200, 200, 200], # 200 bars for each temperature value
    db = "cst",
    exceed_Ttr = True)
# Out:
# Creating data0.cst...
# Finished creating data0.cst.

# %% [markdown]
# Confirm that the data0 file works:

# %%
# load custom data0 file
ae = aqequil.AqEquil(db="cst")

# speciation calculation using the newly-created data0.cst database (200 bars)
speciation = ae.speciate(input_filename="input_example_cst.csv",
                         redox_flag='redox aux',
                         redox_aux='H2',
                         report_filename="report.csv",
                         delete_generated_folders=True)
# Out:
# Loading a user-supplied thermodynamic database...
# data1.cst was not found in the EQ36DA directory but a data0.cst was found in the current working directory. Using it...
# data0.cst is now set as the active thermodynamic database.
# Successfully created a data1.cst from data0.cst
# No 'charge_balance_on' column found in input file. Defaulting to no charge balancing for all samples.
# Using cst to speciate sample A
# Using cst to speciate sample B
# Using cst to speciate sample C
# Using cst to speciate sample D
# Using cst to speciate sample E
# Using cst to speciate sample F
# Using cst to speciate sample G
# Using cst to speciate sample H
# Finished!

# %%
speciation.plot_mass_contribution("acetic-acid")
# Out:
# <iframe
#     scrolling="no"
#     width="508px"
#     height="386"
#     src="iframe_figures/figure_4.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>
