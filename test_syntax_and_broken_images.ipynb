# %%
from test_notebooks import main

# Run tests in current directory
exit_code = main('.')
# Out:
# ...
# WORM-Library Notebook Testing
# ...
#
# Root directory: .
# Excluded folders: WORKSHOP, WORM-Development, WORM-Tour, .ipynb_checkpoints, .git
# Excluded notebooks: WORM-Library.ipynb
#
# Found 63 notebooks to test
#
# Testing: 1-Introduction/1-Introduction.ipynb
#   ✅ All checks passed
#
# Testing: 1-Introduction/2-Notebook-Intro.ipynb
#   ✅ All checks passed
#
# Testing: 1-Introduction/Exploration-In-Geochemistry-(video).ipynb
#   ✅ All checks passed
#
# Testing: 2-Reaction-Properties/1-Reaction-Properties.ipynb
#   ✅ All checks passed
#
# Testing: 2-Reaction-Properties/2-Activity-Diagrams-Part1.ipynb
#   ✅ All checks passed
#
# Testing: 2-Reaction-Properties/2-Activity-Diagrams-Part2.ipynb
#   ✅ All checks passed
#
# Testing: 2-Reaction-Properties/2-Activity-Diagrams-Part3.ipynb
#   ✅ All checks passed
#
# Testing: 2-Reaction-Properties/2-Activity-Diagrams-Part4.ipynb
#   ✅ All checks passed
#
# Testing: 2-Reaction-Properties/2-Activity-Diagrams-Part5.ipynb
#   ✅ All checks passed
#
# ...
