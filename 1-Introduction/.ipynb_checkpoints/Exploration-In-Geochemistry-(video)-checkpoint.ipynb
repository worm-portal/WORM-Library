# %% [markdown]
# <left>
# <table style="margin-top:0px; margin-left:0px;">
# <tr>
#   <td><img src="https://raw.githubusercontent.com/worm-portal/WORM-Figures/master/style/worm.png" alt="WORM" title="WORM" width=50/></td>
#   <td><h1 style=font-size:30px>Into the Field!<br>An Exploration in Geochemistry</h1><br />
# </tr>
# </table>
# </left>
# Featuring Vince Debes, Katelyn Weeks, & Jordyn Robare and edited by Ryan Stewart

# %%
from IPython.lib.display import YouTubeVideo
YouTubeVideo('yDGFVTybljQ', width=560, height=315)

# %% [markdown]
# This presentation shows basic concepts in geochemistry and how scientists work in the field in places like Yellowstone National Park. See a demonstration of gases dissolved in water using a bottle of soda water, and simple water-rock interactions. Our demonstration of fieldwork uses a local water source (Tempe Town Lake, Tempe, AZ), takes temperature, pH, and dissolved oxygen measurements and compares our findings with real samples collected from Yellowstone hot springs! Will there be a difference? Find out how your water source compares to a hot spring.
