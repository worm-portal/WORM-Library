# %% [markdown]
# <left>
# <table style="margin-top:0px; margin-left:0px;">
# <tr>
#   <td><img src="https://raw.githubusercontent.com/worm-portal/WORM-Figures/master/style/worm.png" alt="WORM" title="WORM" width=50/></td>
#   <td><h1 style=font-size:30px>Calculating and Plotting Reaction Properties</h1><br />
# </tr>
# </table>
# </left>

# %% [markdown]
# ### Getting ready
#
# Functions from the pyCHNOSZ and matplotlib packages are used in this demo. Import them with:

# %%
from pychnosz import *
import matplotlib.pyplot as plt
_ = thermo("WORM")
# Out:
# reset: thermodynamic system initialized
# The WORM thermodynamic database has been loaded: 1713 aqueous, 1976 total species

# %% [markdown]
# Use info("name") to search for the index number of a chemical species in the thermodynamic database, [OBIGT](https://chnosz.net/vignettes/OBIGT.html).

# %%
info("Pyri")  # a partial name might result in approximate matches to try
# Out:
# info_approx: 'Pyri' is ambiguous; has approximate matches to 4 species:
#   pyrite
#   chalcopyrite
# nan

# %%
info("pyrite") # case sensitive!
# Out:
# 732

# %% [markdown]
# Use info(index) to get the entry itself.

# %%
info(732)
# Out:
#      name abbrv formula state    ref1 ref2      date    model E_units  \
# 0  pyrite    Py    FeS2    cr  HDNB78  NaN  5/5/1978  CGL_Ttr     cal
#
#          G  ...  Cp      V      a        b         c    d    e    f  lambda  \
# 0 -38293.0  ... NaN  23.94  17.88  0.00132 -305000.0  0.0  0.0  0.0     0.0
#
#         T
# 0  1000.0
#
# [1 rows x 22 columns]

# %% [markdown]
# When Jupyter notebooks abbreviate tables by omitting some columns (indicated by `...`) you can look up all column names in a table with:

# %%
info(732).columns
# Out:
# Index(['name', 'abbrv', 'formula', 'state', 'ref1', 'ref2', 'date', 'model',
#        'E_units', 'G', 'H', 'S', 'Cp', 'V', 'a', 'b', 'c', 'd', 'e', 'f',
#        'lambda', 'T'],
#       dtype='object')

# %% [markdown]
# What do these columns mean? What units are entries in?

# %% [markdown]
# | header | meaning                                                                    |
# | ------ | -------------------------------------------------------------------------- |
# |name    |Species name                                                                |
# |abbrv   |Species abbreviation                                                        |
# |formula |Species formula                                                             |
# |state   |Physical state                                                              |
# |ref1    |Primary source                                                              |
# |ref2    |Secondary source                                                            |
# |date    |Date of data entry                                                          |
# |model   |Model used to calculate properties away from 25  $^\circ$C and 1 bar        |
# |E_units |Units of energy: cal (calories) or J (Joules)                               |
# |G       |Standard molal Gibbs energy of formation from the elements (cal mol$^{-1}$) |
# |H       |Standard molal enthalpy of formation from the elements (cal mol$^{-1}$)     |
# |S       |Standard molal entropy (cal mol$^{-1}$ K$^{-1}$)                            |
# |Cp      |Standard molal isobaric heat capacity (cal mol$^{-1}$ K$^{-1}$)             |
# |V       |Standard molal volume (cm$^{3}$ mol$^{-1}$)                                 |
# |a, b, c... |Parameters that model how properties change with temperature and pressure                                 |

# %% [markdown]
# You can look up the value of any column with square brackets containing the name of the column. For instance, the standard molal entropy `"S"` of chalcopyrite:

# %%
info(732)["S"]
# Out:
# 0    12.65
# Name: S, dtype: float64

# %% [markdown]
# The E_units column for pyrite says "cal", so the units for entropy are cal/mol/K. [Units for each column are discussed on the WORM website](https://worm-portal.asu.edu/docs/database/).

# %% [markdown]
# You can nest two info()s to look up a chemical species directly from its name.

# %%
info(info("pyrite"))
# Out:
#      name abbrv formula state    ref1 ref2      date    model E_units  \
# 0  pyrite    Py    FeS2    cr  HDNB78  NaN  5/5/1978  CGL_Ttr     cal
#
#          G  ...  Cp      V      a        b         c    d    e    f  lambda  \
# 0 -38293.0  ... NaN  23.94  17.88  0.00132 -305000.0  0.0  0.0  0.0     0.0
#
#         T
# 0  1000.0
#
# [1 rows x 22 columns]

# %% [markdown]
# ### Calculate standard state reaction properties
#
# Let's calculate reaction properties for the Knallgas reaction:
#
# $$H_{2(aq)} + \frac{1}{2}O_{2(aq)} = H_{2}O_{}$$
#
# We can use pyCHNOSZ's subcrt() function for this.

# %%
subcrt(
       species=["H2", "O2", "H2O"], # what chemical species are present in rxn?
       coeff=[-1, -0.5, 1] # what are their stoichiometries? negative = reactant
      )
# Out:
# info_character: found H2(aq); also available in gas
# info_character: found O2(aq); also available in gas
# info_character: found H2O(liq) [water]; also available in gas
# subcrt: 3 species at 14 values of T (ºC) and Psat (wet) [energy units: J]
#    coeff   name formula state  ispecies           model
# 0   -1.0     H2      H2    aq        62             HKF
# 1   -0.5     O2      O2    aq        63             HKF
# 2    1.0  water     H2O   liq         1  water.SUPCRT92
#          T         P              G              H           S           V  \
# 0     0.01    1.0001 -263980.310203 -269278.945329  -20.126226  -18.557592
# 1    25.01    1.0001 -263176.154119 -275588.589695  -42.297694  -22.447474
# 2    50.01    1.0001 -261920.543132 -280301.600033  -57.495054  -24.294053
# 3    75.01    1.0001 -260323.918613 -284467.682148  -69.918452  -25.388192
# 4   100.01    1.0137 -258436.643580 -288420.029446  -80.883349  -26.156292
# 5   125.01    2.3210 -256290.470445 -292314.722653  -90.976735  -26.802123
# 6   150.01    4.7586 -253902.103464 -296257.353256 -100.563131  -27.474037
# 7   175.01    8.9203 -251282.297004 -300354.334047 -109.940829  -28.327500
# 8   200.01   15.5399 -248434.924160 -304746.803314 -119.433012  -29.588456
# 9   225.01   25.4835 -245355.640671 -309661.455368 -129.486228  -31.658736
# 10  250.01   39.7434 -242027.941611 -315517.364487 -140.852641  -35.361313
# 11  275.01   59.4405 -238413.973996 -323202.393597 -155.041346  -42.632743
# 12  300.01   85.8501 -234431.648949 -334959.641695 -175.739824  -58.945891
# 13  325.01  120.4734 -229884.916525 -358285.674667 -214.992315 -105.056673
#
#              Cp       logK
# 0   -320.928668  50.478281
# 1   -208.535823  46.104921
# 2   -174.232768  42.335246
# 3   -161.025912  39.055781
# 4   -156.117380  36.175049
# 5   -155.953419  33.622109
# 6   -159.806304  31.340925
# 7   -168.414883  29.287273
# 8   -184.193136  27.425512
# 9   -212.740174  25.726299
# 10  -267.415581  24.164683
# 11  -384.670643  22.718230
# 12  -689.509487  21.364390
# 13 -1817.305201  20.074431
# SubcrtResult with 14 properties calculated

# %% [markdown]
# You can modify subcrt to calculate properties at a specific temperature (T) and pressure (P). If a temperature is given but no pressure, CHNOSZ will perform calculations along the liquid-vapor saturation curve (PSAT).

# %%
subcrt(
    species=["H2", "O2", "H2O"], # what chemical species are present in rxn?
    coeff=[-1, -0.5, 1], # what are their stoichiometries? negative = reactant
    T=350, # degrees C
    P=2000 # bars pressure
      )
# Out:
# info_character: found H2(aq); also available in gas
# info_character: found O2(aq); also available in gas
# info_character: found H2O(liq) [water]; also available in gas
# subcrt: 3 species at 350 ºC and 2000.00 bar (wet) [energy units: J]
#    coeff   name formula state  ispecies           model
# 0   -1.0     H2      H2    aq        62             HKF
# 1   -0.5     O2      O2    aq        63             HKF
# 2    1.0  water     H2O   liq         1  water.SUPCRT92
#        T       P              G              H           S          V  \
# 0  350.0  2000.0 -232976.029309 -331537.004709 -158.485148 -26.814516
#
#            Cp       logK
# 0 -172.399831  19.528495
# SubcrtResult with 1 properties calculated

# %% [markdown]
# This can be done for a range of temperatures and pressures, but be certain the number of T's and P's are the same! (See what happens to the results if they're not!)

# %%
subcrt(
    species=["H2", "O2", "H2O"], # what chemical species are present in rxn?
    coeff=[-1, -0.5, 1], # what are their stoichiometries? negative = reactant
    T=[150, 250, 250.25, 350], # degrees C
    P=[1000, 1050, 1050, 2000] # bars pressure
    )
# Out:
# info_character: found H2(aq); also available in gas
# info_character: found O2(aq); also available in gas
# info_character: found H2O(liq) [water]; also available in gas
# subcrt: 3 species at 4 values of T (ºC) and P (bar) (wet) [energy units: J]
#    coeff   name formula state  ispecies           model
# 0   -1.0     H2      H2    aq        62             HKF
# 1   -0.5     O2      O2    aq        63             HKF
# 2    1.0  water     H2O   liq         1  water.SUPCRT92
#         T       P              G              H           S          V  \
# 0  150.00  1000.0 -256481.844997 -298055.981154  -98.719558 -24.744085
# 1  250.00  1050.0 -245026.716065 -314001.060586 -132.224772 -26.531714
# 2  250.25  1050.0 -244993.649790 -314043.287780 -132.305470 -26.540365
# 3  350.00  2000.0 -232976.029309 -331537.004709 -158.485148 -26.814516
#
#            Cp       logK
# 0 -149.920839  31.660109
# 1 -167.252929  24.464556
# 2 -167.343368  24.449571
# 3 -172.399831  19.528495
# SubcrtResult with 4 properties calculated

# %% [markdown]
# You can change the phase (cr, liq, aq, gas) of a chemical species if an entry exists in the thermodynamic database. Searching for "O2" with info() will reveal that it has entries for "aq" and "gas" phases. Aqueous O2 is selected by default in subcrt(), but we can change it to a gas in our reaction:

# %%
subcrt(
    species=["H2", "O2", "H2O"], # what chemical species are present in rxn?
    coeff=[-1, -0.5, 1], # what are their stoichiometries? negative = reactant
    state=["aq", "gas", "liq"], # what phases are the chemical species in?
    T=350, # degrees C
    P=2000 # bars pressure
    )
# Out:
# subcrt: 3 species at 350 ºC and 2000.00 bar (wet) [energy units: J]
#    coeff   name formula state  ispecies           model
# 0   -1.0     H2      H2    aq        62             HKF
# 1   -0.5  O2(g)      O2   gas       861             CGL
# 2    1.0  water     H2O   liq         1  water.SUPCRT92
#        T       P              G              H          S         V  \
# 0  350.0  2000.0 -216223.994617 -309626.235037 -150.20724 -8.187146
#
#           Cp       logK
# 0 -86.754161  18.124307
# SubcrtResult with 1 properties calculated

# %% [markdown]
# Another example, this time with the reaction:
#
# \begin{align}
# \mathop{\rm{K(AlSi_{3})O_{8}}}\limits_{(K\text{-}feldspar)} + \mathop{\rm{Al_{2}Si_{2}O_{5}(OH)_{4}}}\limits_{(kaolinite)} & \rightleftharpoons \rm{H_{2}O} + \rm{2SiO_{2(aq)}} + \mathop{\rm{KAl_{2}(AlSi_{3})O_{10}(OH)_{2}}}\limits_{(muscovite)} \\
# \end{align}
#
# First, let's check if these entries are in the database:

# %%
info("K-feld") # a partial name might result in approximate matches to try
# Out:
# info_approx: 'K-feld' is similar to K-feldspar [K(AlSi3)O8(cr)] (HDNB78, 5/5/1978)
# nan

# %%
info(info(["K-feldspar", "kaolinite", "muscovite"]))
# Out:
#          name abbrv              formula state    ref1 ref2      date model  \
# 0  K-feldspar  K-Fs           K(AlSi3)O8    cr  HDNB78  NaN  5/5/1978   CGL
# 1   kaolinite   Kln        Al2Si2O5(OH)4    cr  HDNB78  NaN  5/5/1978   CGL
# 2   muscovite    Ms  KAl2(AlSi3)O10(OH)2    cr  HDNB78  NaN  5/5/1978   CGL
#
#   E_units          G  ...  Cp       V       a         b          c    d    e  \
# 0     cal  -895374.0  ... NaN  108.87  76.617  0.004311 -2994500.0  0.0  0.0
# 1     cal  -905614.0  ... NaN   99.52  72.770  0.029200 -2152000.0  0.0  0.0
# 2     cal -1336301.0  ... NaN  140.71  97.560  0.026380 -2544000.0  0.0  0.0
#
#      f  lambda       T
# 0  0.0     0.0  1400.0
# 1  0.0     0.0  1000.0
# 2  0.0     0.0  1000.0
#
# [3 rows x 22 columns]

# %%
subcrt(
    species=["K-feldspar", "kaolinite", "H2O", "SiO2", "muscovite"], # what chemical species are present in rxn?
    coeff=[-1, -1, 1, 2, 1], # what are their stoichiometries? negative = reactant
    T=list(range(0, 360, 50)) # list(range(from, to, by)) to create a sequence. Note that 'to' actually means 'up to but not including'.
)
# Out:
# info_character: found H2O(liq) [water]; also available in gas
# info_character: found SiO2(aq); also available in cr
# subcrt: 5 species at 8 values of T (ºC) and Psat (wet) [energy units: J]
#    coeff        name              formula state  ispecies           model
# 0     -1  K-feldspar           K(AlSi3)O8    cr       807             CGL
# 1     -1   kaolinite        Al2Si2O5(OH)4    cr       791             CGL
# 2      1       water                  H2O   liq         1  water.SUPCRT92
# 3      2        SiO2                 SiO2    aq        67             HKF
# 4      1   muscovite  KAl2(AlSi3)O10(OH)2    cr       803             CGL
#         T         P             G             H           S           V  \
# 0    0.01    1.0001  43552.335798  95872.334604  191.540705  -11.155500
# 1   50.00    1.0001  38481.455405  56345.601777   55.285182  -20.439476
# 2  100.00    1.0134  36384.829763  49296.768166   34.605918  -23.196874
# 3  150.00    4.7573  34712.757026  48795.735922   33.284270  -24.602986
# 4  200.00   15.5366  32955.564829  50019.576103   36.067360  -26.063213
# 5  250.00   39.7366  31032.048280  50694.610601   37.587350  -29.536189
# 6  300.00   85.8380  29104.236600  46345.591844   30.083949  -43.941041
# 7  350.00  165.2114  28148.644623 -10351.576139  -61.781210 -211.501585
#
#             Cp      logK
# 0 -1871.104753 -8.328072
# 1  -287.504642 -6.220101
# 2   -48.985208 -5.093157
# 3    16.035285 -4.284941
# 4    26.868874 -3.638145
# 5   -13.120808 -3.098378
# 6  -271.188918 -2.652394
# 7 -7046.420037 -2.359473
# SubcrtResult with 8 properties calculated

# %% [markdown]
# ### Exporting and plotting results from subcrt

# %% [markdown]
# You can export a table of results into your notebook directory as a downloadable csv.

# %%
my_results = subcrt(
    species=["K-feldspar", "kaolinite", "H2O", "SiO2", "muscovite"], # what chemical species are present in rxn?
    coeff=[-1, -1, 1, 2, 1], # what are their stoichiometries? negative = reactant
    T=list(range(0, 360, 10)), # list(range(from, to, by)) to create a sequence. Note that 'to' actually means 'up to but not including'.
    show=False # don't show me the tables
    )

my_results.out.to_csv("results.csv")
# Out:
# info_character: found H2O(liq) [water]; also available in gas
# info_character: found SiO2(aq); also available in cr
# subcrt: 5 species at 36 values of T (ºC) and Psat (wet) [energy units: J]

# %% [markdown]
# Results can also be plotted directly in a notebook with the matplotlib package:

# %%
fig = plt.figure()
ax = plt.axes()
x = my_results.out["T"]
y = my_results.out["logK"]
plt.xlabel("Temperature, °C")
plt.ylabel("logK")
ax.plot(x, y)
plt.show()

# %% [markdown]
# End of tutorial.
