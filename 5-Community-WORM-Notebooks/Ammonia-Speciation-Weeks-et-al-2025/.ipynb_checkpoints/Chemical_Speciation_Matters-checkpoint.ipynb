# %% [markdown]
# # Chemical Speciation Defines Ammonia-Oxidizer Distribution in Yellowstone Hot Springs
# ### Katelyn Weeks, Elizabeth Trembath-Reichert, Jordyn Robare, R. Vince Debes II, Alta E.G. Howells, Everett Shock

# %% [markdown]
# ### Introduction

# %% [markdown]
# Availability of chemical energy supplies is fundamental to microbial ecology for the characterization of its influence on microbial community composition and function, as well as for investigating the habitability of planetary bodies. The hot springs of Yellowstone National Park (YNP) provide a testing ground for investigating the influence of chemical energy supplies on the presence and abundance of microbial inhabitants.

# %% [markdown]
# ### Getting Started

# %% [markdown]
# Let's take a subset of geochemical data for Yellowstone National Park hot springs collected by the Group Exploring Organic Processes in Geochemistry (GEOPIG) under the research permit #YELL-5434 and calculate the energy supplies available for key microbial metabolisms including total sulfide oxidation, total dissolved ammonia oxidation, iron oxidation to goethite, hydrogen oxidation, and sulfate reduction with $H_2$.

# %% [markdown]
# # Part 1. Let's calculate energy supplies for the 63 hot spring samples included in Figure 1!

# %%
#Loading the required packages
import pandas as pd
import aqequil
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# download the latest CSV versions of the WORM database for later
aqequil.AqEquil(exclude_organics=True, download_csv_files=True)
# Out:
# Loading Water-Organic-Rock-Microbe (WORM) thermodynamic databases...
# Downloading wrm_data_latest.csv from https://raw.githubusercontent.com/worm-portal/WORM-db/master/wrm_data_latest.csv
# Excluding ['organic_aq', 'organic_cr'] from column 'category_1'in wrm_data_latest.csv
# wrm_data_latest.csv is now set as the active thermodynamic database.
# Downloading elements.csv from https://raw.githubusercontent.com/worm-portal/WORM-db/master/elements.csv
# Element database elements.csv is active.
# Downloading solid_solutions.csv from https://raw.githubusercontent.com/worm-portal/WORM-db/master/solid_solutions.csv
# Solid solution database solid_solutions.csv is active.
# Downloading wrm_data_logk.csv from https://raw.githubusercontent.com/worm-portal/WORM-db/master/wrm_data_logK.csv
# Cannot reach https://raw.githubusercontent.com/worm-portal/WORM-db/master/wrm_data_logK.csv, using bundled database: wrm_data_logk.csv
# Copied bundled wrm_data_logk.csv to current working directory
# LogK database wrm_data_logk.csv is active.
# Excluding ['organic_aq', 'organic_cr'] from column 'category_1'in wrm_data_logk.csv
# Downloading wrm_data_logk_s.csv from https://raw.githubusercontent.com/worm-portal/WORM-db/master/wrm_data_logK_S.csv
# LogK_S database wrm_data_logk_s.csv is active.
# Excluding ['organic_aq', 'organic_cr'] from column 'category_1'in wrm_data_logk_s.csv
# Loading thermodynamic database into pyCHNOSZ...

# %%
# load the fast "wrm" database
ae = aqequil.AqEquil(db="wrm")
# Out:
# Loading a user-supplied thermodynamic database...
# data1.wrm is now set as the active thermodynamic database.
# This database is meant for rapid calculations between 0 and 350 °C at water saturation pressure.

# %%
#These compounds need to be suppressed in our calculations
suppress_list = ['CN-', 'N2', 'N2O2-2', 'N2H5+', 'Fe+3', 'S3-2', 'S5-2', 'S2O3-2', 'S2-2', 'SCN-', 'SO3-2', 'HSO5-']

# %%
#Performing speciation calculations on the data used for Figure1
speciation = ae.speciate(input_filename = "Figure1_Data_Input.csv",
                         exclude = ["ID", "Year","Ti+4"],
                         suppress=suppress_list,
                         aq_dist_type="molality",
                         report_filename = 'Fig1_Data_Speciation_Report.csv')
# Out:
# Warning: Could not locate C:\Users\gmboy\Desktop\aqequil\aqequil\databases\data0.wrm. Unable to determine if column headers included in Figure1_Data_Input.csv match entries for species in the requested thermodynamic database 'wrm'.
# The input file column 'logfO2' will be used to set sample redox state. If a another column is desired, set it manually using the redox_flag parameter.
# No 'charge_balance_on' column found in input file. Defaulting to no charge balancing for all samples.
# Warning: no 'logfO2' column found. Attempting to find a column for aqueous O2 to estimate logfO2 at sample temperature and pressure...
# Using wrm to speciate 090723G
# Using wrm to speciate 120724SD
# Using wrm to speciate 120724SC
# Using wrm to speciate 120719SV
# Using wrm to speciate 120715SZ
# Using wrm to speciate 120715SA
# Using wrm to speciate 140805TM
# Using wrm to speciate 140805SY
# Using wrm to speciate 140805SX
# Using wrm to speciate 140803TZ
# Using wrm to speciate 140803SO
# Using wrm to speciate 140803SJ
# Using wrm to speciate 140803SI
# Using wrm to speciate 140803SH
# Using wrm to speciate 140803FN
# Using wrm to speciate 140802TX
# Using wrm to speciate 140802TT
# Using wrm to speciate 140802TS
# Using wrm to speciate 140802TR
# Using wrm to speciate 140802SD
# Using wrm to speciate 140731TP
# Using wrm to speciate 140731ST
# Using wrm to speciate 140731SS
# Using wrm to speciate 140731SQ
# Using wrm to speciate 140731SP
# Using wrm to speciate 140730SM
# Using wrm to speciate 140730SJ
# Using wrm to speciate 140729TZ
# Using wrm to speciate 140729TY
# Using wrm to speciate 140729TA
# Using wrm to speciate 140729SF
# Using wrm to speciate 140729SE
# Using wrm to speciate 140729SD
# Using wrm to speciate 140729SC
# Using wrm to speciate 140729SB
# Using wrm to speciate 140727SX
# Using wrm to speciate 140727SW
# Using wrm to speciate 140727SV
# Using wrm to speciate 140726TR
# Using wrm to speciate 140726TQ
# Using wrm to speciate 140726TN
# Using wrm to speciate 140726TM
# Using wrm to speciate 140726SS
# Using wrm to speciate 140726SR
# Using wrm to speciate 140726SQ
# Using wrm to speciate 140725TK
# Using wrm to speciate 140725SK
# Using wrm to speciate 140725SJ
# Using wrm to speciate 140724TE
# Using wrm to speciate 140724TC
# Using wrm to speciate 140724SE
# Using wrm to speciate 170725TJ
# Using wrm to speciate 170723TU
# Using wrm to speciate 170723TR
# Using wrm to speciate 170719SF
# Using wrm to speciate 170719SE
# Using wrm to speciate 170718TX
# Using wrm to speciate 170718TW
# Using wrm to speciate 170718SX
# Using wrm to speciate 170715SO
# Using wrm to speciate 170714TJ
# Using wrm to speciate 170714SI
# Using wrm to speciate 190730VF
# Finished!

# %% [markdown]
# ## Yay! Our data has been speciated. Let's look at some of the chemotrophic reactions that we can calculate the energy supplies for!

# %%
speciation.thermo.csv_db = pd.read_csv("wrm_data_latest.csv")
speciation.thermo.thermo_db = pd.read_csv("wrm_data_latest.csv")

# %%
#Setting up the 133 chemotrophic reactions used to calculate energy supplies
speciation.make_redox_reactions([2, 7, 16, 17, 18])
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>redox_pairs</th>
#       <th>reaction</th>
#     </tr>
#     <tr>
#       <th>reaction_name</th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>rxn_2_7</th>
#       <td>[2, 7]</td>
#       <td>8 Fe<sup>+2</sup> + 12 H<sub>2</sub>O + SO<sub>4</sub><sup>-2</sup> = 8 goethite + 14 H<sup>+</sup> + H<sub>2</sub>S</td>
#     </tr>
#     <tr>
#       <th>rxn_7_2</th>
#       <td>[7, 2]</td>
#       <td>8 goethite + 14 H<sup>+</sup> + H<sub>2</sub>S = 8 Fe<sup>+2</sup> + 12 H<sub>2</sub>O + SO<sub>4</sub><sup>-2</sup></td>
#     </tr>
#     <tr>
#       <th>rxn_2_16</th>
#       <td>[2, 16]</td>
#       <td>4 NH<sub>3</sub> + 3 SO<sub>4</sub><sup>-2</sup> + 2 H<sup>+</sup> = 4 H<sub>2</sub>O + 4 NO<sub>2</sub><sup>-</sup> + 3 H<sub>2</sub>S</td>
#     </tr>
#     <tr>
#       <th>rxn_16_2</th>
#       <td>[16, 2]</td>
#       <td>4 H<sub>2</sub>O + 4 NO<sub>2</sub><sup>-</sup> + 3 H<sub>2</sub>S = 4 NH<sub>3</sub> + 3 SO<sub>4</sub><sup>-2</sup> + 2 H<sup>+</sup></td>
#     </tr>
#     <tr>
#       <th>rxn_2_17</th>
#       <td>[2, 17]</td>
#       <td>SO<sub>4</sub><sup>-2</sup> + 2 H<sup>+</sup> = 2 O<sub>2</sub> + H<sub>2</sub>S</td>
#     </tr>
#     <tr>
#       <th>rxn_17_2</th>
#       <td>[17, 2]</td>
#       <td>2 O<sub>2</sub> + H<sub>2</sub>S = SO<sub>4</sub><sup>-2</sup> + 2 H<sup>+</sup></td>
#     </tr>
#     <tr>
#       <th>rxn_2_18</th>
#       <td>[2, 18]</td>
#       <td>4 H<sub>2</sub> + SO<sub>4</sub><sup>-2</sup> + 2 H<sup>+</sup> = 4 H<sub>2</sub>O + H<sub>2</sub>S</td>
#     </tr>
#     <tr>
#       <th>rxn_18_2</th>
#       <td>[18, 2]</td>
#       <td>4 H<sub>2</sub>O + H<sub>2</sub>S = 4 H<sub>2</sub> + SO<sub>4</sub><sup>-2</sup> + 2 H<sup>+</sup></td>
#     </tr>
#     <tr>
#       <th>rxn_7_16</th>
#       <td>[7, 16]</td>
#       <td>NH<sub>3</sub> + 6 goethite + 11 H<sup>+</sup> = 6 Fe<sup>+2</sup> + 10 H<sub>2</sub>O + NO<sub>2</sub><sup>-</sup></td>
#     </tr>
#     <tr>
#       <th>rxn_16_7</th>
#       <td>[16, 7]</td>
#       <td>6 Fe<sup>+2</sup> + 10 H<sub>2</sub>O + NO<sub>2</sub><sup>-</sup> = NH<sub>3</sub> + 6 goethite + 11 H<sup>+</sup></td>
#     </tr>
#     <tr>
#       <th>rxn_7_17</th>
#       <td>[7, 17]</td>
#       <td>4 goethite + 8 H<sup>+</sup> = 4 Fe<sup>+2</sup> + 6 H<sub>2</sub>O + O<sub>2</sub></td>
#     </tr>
#     <tr>
#       <th>rxn_17_7</th>
#       <td>[17, 7]</td>
#       <td>4 Fe<sup>+2</sup> + 6 H<sub>2</sub>O + O<sub>2</sub> = 4 goethite + 8 H<sup>+</sup></td>
#     </tr>
#     <tr>
#       <th>rxn_7_18</th>
#       <td>[7, 18]</td>
#       <td>H<sub>2</sub> + 4 H<sup>+</sup> + 2 goethite = 2 Fe<sup>+2</sup> + 4 H<sub>2</sub>O</td>
#     </tr>
#     <tr>
#       <th>rxn_18_7</th>
#       <td>[18, 7]</td>
#       <td>2 Fe<sup>+2</sup> + 4 H<sub>2</sub>O = H<sub>2</sub> + 4 H<sup>+</sup> + 2 goethite</td>
#     </tr>
#     <tr>
#       <th>rxn_16_17</th>
#       <td>[16, 17]</td>
#       <td>2 H<sub>2</sub>O + 2 NO<sub>2</sub><sup>-</sup> + 2 H<sup>+</sup> = 2 NH<sub>3</sub> + 3 O<sub>2</sub></td>
#     </tr>
#     <tr>
#       <th>rxn_17_16</th>
#       <td>[17, 16]</td>
#       <td>2 NH<sub>3</sub> + 3 O<sub>2</sub> = 2 H<sub>2</sub>O + 2 NO<sub>2</sub><sup>-</sup> + 2 H<sup>+</sup></td>
#     </tr>
#     <tr>
#       <th>rxn_16_18</th>
#       <td>[16, 18]</td>
#       <td>3 H<sub>2</sub> + NO<sub>2</sub><sup>-</sup> + H<sup>+</sup> = NH<sub>3</sub> + 2 H<sub>2</sub>O</td>
#     </tr>
#     <tr>
#       <th>rxn_18_16</th>
#       <td>[18, 16]</td>
#       <td>NH<sub>3</sub> + 2 H<sub>2</sub>O = 3 H<sub>2</sub> + NO<sub>2</sub><sup>-</sup> + H<sup>+</sup></td>
#     </tr>
#     <tr>
#       <th>rxn_17_18</th>
#       <td>[17, 18]</td>
#       <td>2 H<sub>2</sub> + O<sub>2</sub> = 2 H<sub>2</sub>O</td>
#     </tr>
#     <tr>
#       <th>rxn_18_17</th>
#       <td>[18, 17]</td>
#       <td>2 H<sub>2</sub>O = 2 H<sub>2</sub> + O<sub>2</sub></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Let's calculate and create a spreadsheet for our energy supplies!

# %%
#Calculating the energy supply for the chemotrophic reactions above
df = speciation.apply_redox_reactions(y_type='E',
                                      y_units='J')

#Creating a '.csv' of the energy supply results
df.to_csv("Figure1_Energy_Report.csv")
# Out:
# IntProgress(value=0, max=20)

# %% [markdown]
# ### Selecting the energy supplies of interest and formatting the data frame

# %%
# Creating a data frame that only includes the 5 chemotrophic reactions included in Figure 1
df = pd.read_csv("Figure1_Energy_Report.csv")
Microbially_Relevant_Reactions = df[['rxn_17_2 energy supply', 'rxn_2_18 energy supply', 'rxn_17_16 energy supply', 'rxn_17_18 energy supply', 'rxn_17_7 energy supply']]

# Naming the reactions
Microbially_Relevant_Reactions = Microbially_Relevant_Reactions.rename(columns={
    'rxn_17_2 energy supply': 'Total Sulfide Oxidation',
    'rxn_2_18 energy supply': 'Sulfate Reduction with H2',
    'rxn_17_16 energy supply': 'Total Dissolved Ammonia Oxidation',
    'rxn_17_18 energy supply': 'Hydrogen Oxidation',
    'rxn_17_7 energy supply': 'Iron Oxidation to Goethite'
})

#Looking at the head of the file
Microbially_Relevant_Reactions.head()
# Out:
#   Total Sulfide Oxidation Sulfate Reduction with H2  \
# 0              J/kg fluid                J/kg fluid
# 1      2.1824021444846022       0.00556038327676607
# 2      0.7338643911465171     0.0013882967635493464
# 3        0.43206924554889     0.0018437552131126025
# 4       1.338517393129899     0.0028776792365710568
#
#   Total Dissolved Ammonia Oxidation    Hydrogen Oxidation  \
# 0                        J/kg fluid            J/kg fluid
# 1                31.108058363656394   0.05464580252875701
# 2                 6.062324901693168  0.019184734783468545
# 3                2.2299536568001845  0.023023620190999364
# 4                1.9269907161667028   0.01879444555366455
#
#   Iron Oxidation to Goethite
# 0                 J/kg fluid
# 1         0.5996974122897522
# 2        0.01754191817068282
# 3        0.03691740966513842
# 4        0.02355186302688064

# %%
# Use pd.melt to convert the dataframe from wide to long form. This is required for creating a violin plot.
Microbially_Relevant_Reactions_long = pd.melt(
    Microbially_Relevant_Reactions, 
    var_name='Reaction',  # The new column that will hold the original column names
    value_name='Energy Supply (J/kg)'    # The new column that will hold the values
)

# Display the transformed dataframe
# Convert 'Value' column to numeric, converting strings to NaN
Microbially_Relevant_Reactions_long['Energy Supply (J/kg)'] = pd.to_numeric(Microbially_Relevant_Reactions_long['Energy Supply (J/kg)'], errors='coerce')

# Drop rows with NaN values in the 'Value' column (which were originally strings)
Microbially_Relevant_Reactions_long_cleaned = Microbially_Relevant_Reactions_long.dropna(subset=['Energy Supply (J/kg)'])

# Display the cleaned DataFrame
print(Microbially_Relevant_Reactions_long_cleaned)
# Out:
#                        Reaction  Energy Supply (J/kg)
# 1       Total Sulfide Oxidation              2.182402
# 2       Total Sulfide Oxidation              0.733864
# 3       Total Sulfide Oxidation              0.432069
# 4       Total Sulfide Oxidation              1.338517
# 5       Total Sulfide Oxidation              0.298471
# ..                          ...                   ...
# 315  Iron Oxidation to Goethite              0.018269
# 316  Iron Oxidation to Goethite              1.556243
# 317  Iron Oxidation to Goethite              0.399728
# 318  Iron Oxidation to Goethite              0.147390
# 319  Iron Oxidation to Goethite              1.165313
#
# [315 rows x 2 columns]

# %%
# Convert 'Value' column to numeric, forcing errors to NaN
#Microbially_Relevant_Reactions_long_cleaned['Energy Supply (J/kg)'] = pd.to_numeric(Microbially_Relevant_Reactions_long_cleaned['Energy Supply (J/kg)'], errors='coerce')

Microbially_Relevant_Reactions_long_cleaned.loc[:, 'Energy Supply (J/kg)'] = pd.to_numeric(Microbially_Relevant_Reactions_long_cleaned['Energy Supply (J/kg)'], errors='coerce')

# Now apply log10 transformation, ignoring any NaN values
Microbially_Relevant_Reactions_long_cleaned.loc[:, 'Log_Energy Supply (J/kg)'] = np.log10(Microbially_Relevant_Reactions_long_cleaned['Energy Supply (J/kg)'])

# Display the updated dataframe to check for any NaN entries
print(Microbially_Relevant_Reactions_long_cleaned.head())
# Out:
#                   Reaction  Energy Supply (J/kg)  Log_Energy Supply (J/kg)
# 1  Total Sulfide Oxidation              2.182402                  0.338935
# 2  Total Sulfide Oxidation              0.733864                 -0.134384
# 3  Total Sulfide Oxidation              0.432069                 -0.364447
# 4  Total Sulfide Oxidation              1.338517                  0.126624
# 5  Total Sulfide Oxidation              0.298471                 -0.525099

# %% [markdown]
# # Figure 1
# ### Time to make figure 1. Let's compare some relavent chemotrophic energy supplies using a violin plot.

# %% [markdown]
# ### First we need to cut down our data to the chemotrophic reactions we care about. Then, we will need to "melt" our data to get it in the proper format for making a violin plot. The violin plot will be made using MatPlot Lib and Seaborn, but Rstudio and ggplot2 were used for Weeks et al., 2024.

# %%
# Create the violin plot
plt.figure(figsize=(10, 6))  # Optional: Set the figure size
sns.violinplot(x='Reaction', y='Log_Energy Supply (J/kg)', data=Microbially_Relevant_Reactions_long_cleaned)

# Add title and labels
plt.title('Violin Plot of Microbially Relevant Reactions')
plt.xlabel('Reaction')
plt.ylabel('Energy Supply (J/kg)')

# Show the plot
plt.xticks(rotation=45)  # Optional: Rotate x-axis labels if needed
plt.tight_layout()       # Adjust layout for better fitting
plt.show()

# %% [markdown]
# # Part 2. Is the high energy supply for total dissolved ammonia oxidation reflected in the distribution of the known AOA (*Ca. Nitrosocaldus yellowstonensis*) among YNP hot springs?

# %% [markdown]
# We need to calculate the energy supply for total dissolved ammonia oxidation for the samples included for which we have 16S rRNA gene amplicon data. The relative abundances of *Ca. Nitrosocaldus yellowstonensis* have already been calculated and are included in the data input file in the column titled "AOA RA".

# %%
#Reloading required packages. 
import pandas as pd
import aqequil
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

ae = aqequil.AqEquil(db="wrm")
# Out:
# Loading a user-supplied thermodynamic database...
# data1.wrm is now set as the active thermodynamic database.
# This database is meant for rapid calculations between 0 and 350 °C at water saturation pressure.

# %%
suppress_list = ['CN-', 'N2', 'N2O2-2', 'N2H5+', 'Fe+3', 'S3-2', 'S5-2', 'S2O3-2', 'S2-2', 'SCN-', 'SO3-2', 'HSO5-']

# %%
speciation_of_Fig2_Data = ae.speciate(
        input_filename = "Figure2_Data_Input.csv",
        exclude = ["Sample", "Year", "AOA", "DOC", "AOA RA"],
        suppress=suppress_list,
        aq_dist_type="molality",
        report_filename = 'Figure2_Data_Speciation_Report.csv',
        )
# Out:
# Warning: Could not locate C:\Users\gmboy\Desktop\aqequil\aqequil\databases\data0.wrm. Unable to determine if column headers included in Figure2_Data_Input.csv match entries for species in the requested thermodynamic database 'wrm'.
# The input file column 'logfO2' will be used to set sample redox state. If a another column is desired, set it manually using the redox_flag parameter.
# No 'charge_balance_on' column found in input file. Defaulting to no charge balancing for all samples.
# Warning: no 'logfO2' column found. Attempting to find a column for aqueous O2 to estimate logfO2 at sample temperature and pressure...
# Using wrm to speciate 140724SC
# Using wrm to speciate 140724SD
# Using wrm to speciate 140724SE
# Using wrm to speciate 140725SI
# Using wrm to speciate 140725SJ
# Using wrm to speciate 140725SK
# Using wrm to speciate 140725SL
# Using wrm to speciate 140726SO
# Using wrm to speciate 140726SP
# Using wrm to speciate 140726SQ
# Using wrm to speciate 140726SR
# Using wrm to speciate 140727SU
# Using wrm to speciate 140727SV
# Using wrm to speciate 140727SW
# Using wrm to speciate 140727SX
# Using wrm to speciate 140727SY
# Using wrm to speciate 140727SZ
# Using wrm to speciate 140729SD
# Using wrm to speciate 140729SE
# Using wrm to speciate 140730SI
# Using wrm to speciate 140730SJ
# Using wrm to speciate 140730SK
# Using wrm to speciate 140730SL
# Using wrm to speciate 140730SN
# Using wrm to speciate 140731SP
# Using wrm to speciate 140731SQ
# Using wrm to speciate 140731SR
# Using wrm to speciate 140802SA
# Using wrm to speciate 140802SB
# Using wrm to speciate 140802SC
# Using wrm to speciate 140803SG
# Using wrm to speciate 140803SH
# Using wrm to speciate 140803SI
# Using wrm to speciate 140803SJ
# Using wrm to speciate 140803SO
# Using wrm to speciate 140803SP
# Using wrm to speciate 140804SS
# Using wrm to speciate 140804ST
# Using wrm to speciate 140804SU
# Using wrm to speciate 140804SV
# Using wrm to speciate 140805SA
# Using wrm to speciate 140805SB
# Using wrm to speciate 140805SC
# Using wrm to speciate 140805SD
# Using wrm to speciate 140805SE
# Using wrm to speciate 140805SZ
# Using wrm to speciate 210715TA
# Using wrm to speciate 210716SE
# Using wrm to speciate 210716SG
# Using wrm to speciate 210721TR
# Using wrm to speciate 210721TS
# Using wrm to speciate 210722TW
# Using wrm to speciate 210722TX
# Using wrm to speciate 210724TB
# Using wrm to speciate 210724TD
# Using wrm to speciate 210725TJ
# Using wrm to speciate 210726SX
# Using wrm to speciate 210726SY
# Using wrm to speciate 210727TT
# Using wrm to speciate 210727TU
# Using wrm to speciate 220721SB
# Using wrm to speciate 220722SE
# Using wrm to speciate 220724TP
# Using wrm to speciate 220726SR
# Using wrm to speciate 220726SS
# Using wrm to speciate 220730SF
# Using wrm to speciate 220730SG
# Using wrm to speciate 220731SN
# Using wrm to speciate 190718ZC
# Using wrm to speciate 190718ZD
# Using wrm to speciate 190719ZE
# Using wrm to speciate 190719ZF
# Using wrm to speciate 190719ZH
# Using wrm to speciate 190720ZK
# Using wrm to speciate 190720ZL
# Using wrm to speciate 190720ZO
# Using wrm to speciate 190721VQ
# Using wrm to speciate 190721VR
# Using wrm to speciate 190723VW
# Warning: the sample 190723VZ may be outside of the stability region of water (too oxidized) which may cause the speciation calculation to fail. The sample has a logfO2 of 0.01, which is above the 0 logfO2 threshold for stable water at this temperature and pressure.
# Using wrm to speciate 190723VZ
# Warning: non-numeric aqueous O2 value in sample 190724VA. Resorting to using Log fO2 (log bars) with a value of -6
# Using wrm to speciate 190724VA
# Using wrm to speciate 190725ZG
# Using wrm to speciate 190727VP
# Using wrm to speciate 190727ZK
# Using wrm to speciate 190728VU
# Using wrm to speciate 190728ZQ
# Using wrm to speciate 190728ZS
# Using wrm to speciate 190728ZT
# Warning: non-numeric aqueous O2 value in sample 190728ZU. Resorting to using Log fO2 (log bars) with a value of -6
# Using wrm to speciate 190728ZU
# Using wrm to speciate 190728ZV
# Using wrm to speciate 190729VX
# Using wrm to speciate 190730VC
# Using wrm to speciate 190730VE
# Using wrm to speciate 190730VF
# Using wrm to speciate 190730VG
# Using wrm to speciate 210715SA
# Using wrm to speciate 210716TG
# Using wrm to speciate 210724SL
# Using wrm to speciate 210724SK
# C:\Users\gmboy\Desktop\aqequil\aqequil\preprocess_for_EQ3.py:471: RuntimeWarning:
#
# divide by zero encountered in log10
# Using wrm to speciate 210722SD
# Using wrm to speciate 210720SY
# Using wrm to speciate 210730TA
# Using wrm to speciate 210718TJ
# Using wrm to speciate 210725SQ
# Using wrm to speciate 210725SR
# Using wrm to speciate 210725TL
# Finished!

# %%
speciation_of_Fig2_Data.thermo.csv_db = pd.read_csv("wrm_data_latest.csv")

# %%
#Saving the speciation product
speciation_of_Fig2_Data.save("Total_Ammonia_Oxidation_Speciation")
# Out:
# Saved as 'Total_Ammonia_Oxidation_Speciation.speciation'

# %%
#Performing the energy supply calculation for total dissolved ammonia oxidation only
df = speciation_of_Fig2_Data.calculate_energy(
        y_type = "E",
        y_units = "J",
        species = ["NH4+", "O2", "H+", "H2O", "NO2-"],
        stoich = [-1, -1.5, 2, 1, 1],
        as_written = False,
        rxn_name = "Total Dissolved Ammonia Oxidation (J/kg)")

# %%
#Print energy calculations to a csv
df.to_csv("Figure2_Energy_Report.csv")

# %%
#Combining energy report with initial input data for ease of plotting

#Reading in files
Figure_2_Energy_Report = pd.read_csv("Figure2_Energy_Report.csv")
Figure2_Data_Speciation = pd.read_csv("Figure2_Data_Speciation_Report.csv")

#Merging data files
Figure_2_Data_Combined = pd.merge(Figure_2_Energy_Report, Figure2_Data_Speciation , on='Sample')
Figure_2_Data_Combined.to_csv("Figure_2_Data_Combined.csv")

#Viewing the head of the new dataframe
Figure_2_Data_Combined.head()
# Out:
#      Sample Total Dissolved Ammonia Oxidation (J/kg) energy supply  \
# 0       NaN                                         J/kg fluid
# 1  140724SC                                  6.545446355229326
# 2  140724SD                                 6.8645218979131295
# 3  140724SE                                 5.5694887707711045
# 4  140725SI                                 0.9261891133456535
#
#   Total Dissolved Ammonia Oxidation (J/kg) limiting reactant    Year     AOA  \
# 0                                  limiting reactant             NaN  Yes/No
# 1                                               NH4+          2014.0     Yes
# 2                                               NH4+          2014.0     Yes
# 3                                               NH4+          2014.0     Yes
# 4                                               NH4+          2014.0     Yes
#
#      AOA RA Temperature            Pressure pH_(input) HCO3-_(input)  ...  \
# 0       NaN        degC                 bar         pH      Molality  ...
# 1  3.137337        50.0  1.0000000000000018      7.993      4.25E-04  ...
# 2  1.321815        54.8                 1.0      7.745      4.71E-04  ...
# 3  5.339491        70.2                 1.0       7.13      4.90E-04  ...
# 4  0.156292        59.2                 1.0      9.034      3.10E-04  ...
#
#   Mg+2_total NH4+_total NO2-_total NO3-_total  Na+_total  O2_total  \
# 0   molality   molality   molality   molality   molality  molality
# 1   6.41e-06   2.29e-05    1.7e-07   1.77e-07  0.0145001  8.13e-05
# 2   6.79e-06   2.43e-05   2.08e-07   2.42e-07  0.0142611  7.19e-05
# 3   6.63e-06   1.99e-05   4.62e-08   1.16e-07  0.0139516   7.5e-05
# 4        NaN   3.19e-06   1.55e-07   9.35e-08  0.0136697   7.5e-05
#
#      OH-_total PO4-3_total  SO4-2_total SiO2_total
# 0     molality    molality     molality   molality
# 1  8.76217e-06    1.24e-07   0.00110446   5.51e-06
# 2          NaN    1.71e-07   0.00110134   5.31e-06
# 3          NaN         NaN   0.00107501   4.41e-06
# 4  0.000148773    1.34e-07  0.000173258   7.97e-06
#
# [5 rows x 252 columns]

# %%
#Formatting the data frame

#Removing the first row so we are only including headers and values
Figure_2_Data_Combined = Figure_2_Data_Combined.iloc[1:]

# List of columns to convert to float
columns = ['pH_(input)', 'O2_(input)', 'Temperature', 'NH3', 'NH4+', 'NH4+_(input)', 'Total Dissolved Ammonia Oxidation (J/kg) energy supply']

# Convert the selected columns to floats
for c in columns:
    Figure_2_Data_Combined[c] = Figure_2_Data_Combined[c].astype(float)

# Display the updated DataFrame to check the changes
Figure_2_Data_Combined.head()
# Out:
#      Sample  Total Dissolved Ammonia Oxidation (J/kg) energy supply  \
# 1  140724SC                                           6.545446
# 2  140724SD                                           6.864522
# 3  140724SE                                           5.569489
# 4  140725SI                                           0.926189
# 5  140725SJ                                           1.148661
#
#   Total Dissolved Ammonia Oxidation (J/kg) limiting reactant    Year  AOA  \
# 1                                               NH4+          2014.0  Yes
# 2                                               NH4+          2014.0  Yes
# 3                                               NH4+          2014.0  Yes
# 4                                               NH4+          2014.0  Yes
# 5                                               NH4+          2014.0   No
#
#      AOA RA  Temperature            Pressure  pH_(input) HCO3-_(input)  ...  \
# 1  3.137337         50.0  1.0000000000000018       7.993      4.25E-04  ...
# 2  1.321815         54.8                 1.0       7.745      4.71E-04  ...
# 3  5.339491         70.2                 1.0       7.130      4.90E-04  ...
# 4  0.156292         59.2                 1.0       9.034      3.10E-04  ...
# 5  0.000000         64.6                 1.0       9.044      3.58E-05  ...
#
#   Mg+2_total  NH4+_total NO2-_total NO3-_total  Na+_total  O2_total  \
# 1   6.41e-06    2.29e-05    1.7e-07   1.77e-07  0.0145001  8.13e-05
# 2   6.79e-06    2.43e-05   2.08e-07   2.42e-07  0.0142611  7.19e-05
# 3   6.63e-06    1.99e-05   4.62e-08   1.16e-07  0.0139516   7.5e-05
# 4        NaN    3.19e-06   1.55e-07   9.35e-08  0.0136697   7.5e-05
# 5        NaN    4.01e-06   1.76e-07   7.42e-07  0.0137037  2.81e-05
#
#      OH-_total PO4-3_total  SO4-2_total SiO2_total
# 1  8.76217e-06    1.24e-07   0.00110446   5.51e-06
# 2          NaN    1.71e-07   0.00110134   5.31e-06
# 3          NaN         NaN   0.00107501   4.41e-06
# 4  0.000148773    1.34e-07  0.000173258   7.97e-06
# 5  0.000162242    1.23e-07  0.000172341   7.41e-06
#
# [5 rows x 252 columns]

# %% [markdown]
# Now let's plot this data!

# %% [markdown]
# ## Figure 2A. AOA distribution as a function of pH and temperature.

# %%
# Set plot style
sns.set(style="whitegrid")

# Create a scatter plot
plt.figure(figsize=(10, 6))

#Setting marker shapes based on whether AOA were detected (Yes; triangles) or were not detected (No; 'X's)
markers= {"Yes": "^", "No": "X"}

# Plot with Seaborn, using 'hue' for point shapes
sns.scatterplot(
    data=Figure_2_Data_Combined,
    x='Temperature',
    y='pH_(input)',
    style='AOA',  # Set different point shapes based on 'AOA'
    markers=markers,
    s = 200, #setting point size
)

# Add labels and title
plt.xlabel('Temperature (°C)')
plt.ylabel('pH')

# Show the plot
plt.show()

# %% [markdown]
# ## Figure 2B. AOA distribution as a function of pH, temperature, and the energy supply for total dissolved ammonia oxidation.

# %%
# Set plot style
sns.set(style="whitegrid")

# Create a scatter plot
plt.figure(figsize=(10, 6))

#Setting marker shapes based on whether AOA were detected (Yes; triangles) or were not detected (No; 'X's)
markers= {"Yes": "^", "No": "X"}

# Plot with Seaborn, using 'hue' for point shapes
Figure2b = sns.scatterplot(
    data=Figure_2_Data_Combined,
    x='Temperature',
    y='pH_(input)',
    style='AOA',  # Set different point shapes based on 'AOA'
    markers=markers, #Setting marker shape
    s = 200, #setting point size
    hue= 'Total Dissolved Ammonia Oxidation (J/kg) energy supply',
    palette= "viridis" #Setting color based on the energy supply
)

# Add labels and title
plt.xlabel('Temperature (°C)')
plt.ylabel('pH')
sns.move_legend(Figure2b, "upper left", bbox_to_anchor=(1, 1))

# Show the plot
plt.show()

# %% [markdown]
# # Part 3. The high energy supply for total dissolved ammonia oxidation is not reflected in the distribution of AOA. Which geochemical parameters *do* influence AOA distribution?

# %% [markdown]
# Let's start by determining the limiting reactant of the total dissolved ammonia oxidation reaction. We can then plot the distribution of AOA as a function of the limiting reactant to see if the limiting reactant influences AOA distribution.
#
# To calculate which reactant is limiting to the reaction, we will take the log of the molality of the electron donor (total dissolved ammonia; represented by $NH_4^+$) divided by the molality of the electron acceptor ($O_2$). We also need to account for stoichiometry by dividing $O_2$ by 1.5. This written reaction looks like the following:
#
# $$
# \log_{10}\left[\frac{NH_4^+}{\frac{O_2}{1.5}}\right]
# $$
#
# Based off the chemical equation:
#
# $$
# NH_4^+ + 1.5 O_2 \rightarrow NO_2^- + H_2O + 2H^+
# $$

# %%
# Remove rows where 'O2_(input)' or 'NH4+_(input)' are 0 so we can perform a log function
Figure_2_Data_Combined_Cut = Figure_2_Data_Combined[(Figure_2_Data_Combined['O2_(input)'] != 0) & (Figure_2_Data_Combined['NH4+_(input)'] != 0)].copy()

# Add a new column with the specified calculation
Figure_2_Data_Combined_Cut.loc[:, 'Log of the limiting reactant'] = np.log10(Figure_2_Data_Combined_Cut['NH4+_(input)'] / (Figure_2_Data_Combined_Cut['O2_(input)'])/1.5)

# Display the updated DataFrame
Figure_2_Data_Combined_Cut.head()
# Out:
#      Sample  Total Dissolved Ammonia Oxidation (J/kg) energy supply  \
# 1  140724SC                                           6.545446
# 2  140724SD                                           6.864522
# 3  140724SE                                           5.569489
# 4  140725SI                                           0.926189
# 5  140725SJ                                           1.148661
#
#   Total Dissolved Ammonia Oxidation (J/kg) limiting reactant    Year  AOA  \
# 1                                               NH4+          2014.0  Yes
# 2                                               NH4+          2014.0  Yes
# 3                                               NH4+          2014.0  Yes
# 4                                               NH4+          2014.0  Yes
# 5                                               NH4+          2014.0   No
#
#      AOA RA  Temperature            Pressure  pH_(input) HCO3-_(input)  ...  \
# 1  3.137337         50.0  1.0000000000000018       7.993      4.25E-04  ...
# 2  1.321815         54.8                 1.0       7.745      4.71E-04  ...
# 3  5.339491         70.2                 1.0       7.130      4.90E-04  ...
# 4  0.156292         59.2                 1.0       9.034      3.10E-04  ...
# 5  0.000000         64.6                 1.0       9.044      3.58E-05  ...
#
#   NH4+_total  NO2-_total NO3-_total  Na+_total  O2_total    OH-_total  \
# 1   2.29e-05     1.7e-07   1.77e-07  0.0145001  8.13e-05  8.76217e-06
# 2   2.43e-05    2.08e-07   2.42e-07  0.0142611  7.19e-05          NaN
# 3   1.99e-05    4.62e-08   1.16e-07  0.0139516   7.5e-05          NaN
# 4   3.19e-06    1.55e-07   9.35e-08  0.0136697   7.5e-05  0.000148773
# 5   4.01e-06    1.76e-07   7.42e-07  0.0137037  2.81e-05  0.000162242
#
#   PO4-3_total  SO4-2_total SiO2_total Log of the limiting reactant
# 1    1.24e-07   0.00110446   5.51e-06                    -0.726346
# 2    1.71e-07   0.00110134   5.31e-06                    -0.647214
# 3         NaN   0.00107501   4.41e-06                    -0.752299
# 4    1.34e-07  0.000173258   7.97e-06                    -1.547362
# 5    1.23e-07  0.000172341   7.41e-06                    -1.021653
#
# [5 rows x 253 columns]

# %% [markdown]
# ## Figure 3a. AOA distribution as a function of temperature and the limiting reactant

# %%
# Set plot style
sns.set(style="whitegrid")

# Create a scatter plot
plt.figure(figsize=(10, 6))

#Setting marker shapes based on whether AOA were detected (Yes; triangles) or were not detected (No; 'X's)
markers= {"Yes": "^", "No": "X"}

# Plot with Seaborn, using 'hue' for point shapes
Figure3a = sns.scatterplot(
    data=Figure_2_Data_Combined_Cut,
    x='Temperature',
    y='Log of the limiting reactant',
    style='AOA',  # Set different point shapes based on 'AOA'
    markers=markers, #Setting marker shape
    s = 200, #setting point size
)

# Add labels and title
plt.xlabel('Temperature (°C)')
plt.ylabel('Log[(electron donor)/(electron acceptor)]')
plt.axhline(y=0)
sns.move_legend(Figure3a, "upper left", bbox_to_anchor=(1, 1))

# Show the plot
plt.show()

# %% [markdown]
# Positive values correspond to conditions where oxygen is the limiting reactant, and negative values to those where total dissolved ammonia is limiting. The majority of samples in which AOA were detected are constrained to hot springs where total dissolved ammonia is limiting.

# %% [markdown]
# ## Figure 3b. AOA distribution as a function of total dissolved ammonia and $O_2$

# %%
# Set plot style
sns.set(style="whitegrid")

# Create a scatter plot
plt.figure(figsize=(10, 6))

# Setting marker shapes based on whether AOA were detected (Yes; triangles) or were not detected (No; 'X's)
markers = {"Yes": "^", "No": "X"}

# Plot with Seaborn, using 'style' for point shapes
Figure3b = sns.scatterplot(
    data=Figure_2_Data_Combined,
    x='O2_(input)',
    y='NH4+_(input)',
    style='AOA',  # Set different point shapes based on 'AOA'
    markers=markers,  # Setting marker shape
    s=200  # Setting point size
)

# Set the x-axis and y-axis to log scale
plt.xscale('log')
plt.yscale('log')

# Add labels and title
plt.xlabel('Dissolved Oxygen (molality)')
plt.ylabel('Total Dissolved Ammonia (molality)')
plt.axhline(y=0.0000265)

# Move the legend
sns.move_legend(Figure3b, "upper left", bbox_to_anchor=(1, 1))

# Show the plot
plt.show()

# %% [markdown]
# AOA distribution is constrained to lower total dissolved ammonia (molality).

# %% [markdown]
# ## Figure 3c. AOA distribution as a function of $NH_3(aq)$ and $O_2$

# %%
# Set plot style
sns.set(style="whitegrid")

# Create a scatter plot
plt.figure(figsize=(10, 6))

# Setting marker shapes based on whether AOA were detected (Yes; triangles) or were not detected (No; 'X's)
markers = {"Yes": "^", "No": "X"}

# Plot with Seaborn, using 'style' for point shapes
Figure3c = sns.scatterplot(
    data=Figure_2_Data_Combined,
    x='O2_(input)',
    y='NH3',
    style='AOA',  # Set different point shapes based on 'AOA'
    markers=markers,  # Setting marker shape
    s=200  # Setting point size
)

# Set the x-axis and y-axis to log scale
plt.xscale('log')
plt.yscale('log')

# Add labels and title
plt.xlabel('Dissolved Oxygen (molality)')
plt.ylabel('NH3(aq) (molality)')
plt.axhline(y=0.00000007)

# Move the legend
sns.move_legend(Figure3c, "upper left", bbox_to_anchor=(1, 1))

# Show the plot
plt.show()

# %% [markdown]
# AOA distribution is constrained to high $NH_3(aq)$ concentrations (> 0.07 μmolal).

# %% [markdown]
# ## Figure 3d. AOA distribution as a function of $NH_4^+$ and $O_2$

# %%
# Set plot style
sns.set(style="whitegrid")

# Create a scatter plot
plt.figure(figsize=(10, 6))

# Setting marker shapes based on whether AOA were detected (Yes; triangles) or were not detected (No; 'X's)
markers = {"Yes": "^", "No": "X"}

# Plot with Seaborn, using 'style' for point shapes
Figure3d = sns.scatterplot(
    data=Figure_2_Data_Combined,
    x='O2_(input)',
    y='NH4+',
    style='AOA',  # Set different point shapes based on 'AOA'
    markers=markers,  # Setting marker shape
    s=200  # Setting point size
)

# Set the x-axis and y-axis to log scale
plt.xscale('log')
plt.yscale('log')

# Add labels and title
plt.xlabel('Dissolved Oxygen (molality)')
plt.ylabel('NH4+ (molality)')
plt.axhline(y=0.0000205)

# Move the legend
sns.move_legend(Figure3d, "upper left", bbox_to_anchor=(1, 1))

# Show the plot
plt.show()

# %% [markdown]
# AOA distribution is constrained to low $NH_4^+$ concentrations (<20.5 μmolal).

# %% [markdown]
# Neither the distribution nor the abundance of AOA correlate with the energy supply available from total dissolved ammonia oxidation, total dissolved ammonia, or dissolved oxygen. Instead, the form that the total dissolved ammonia takes, which is predominantly $NH_4^+$ at pH values lower than the pKa and $NH_3(aq)$ at pH values higher than the pKa, has higher explanatory power for AOA distribution. Speciating total dissolved ammonia measurements to determine actual substrate availability in terms of $NH_3(aq)$ not only supports the results of in-lab experiments but has also revealed an environmental lower threshold for substrate availability for *Nitrosocaldus yellowstonensis* at 0.07 μmolality.

# %% [markdown]
# # Part 4. Since it is the form that total dissolved ammonia takes ($NH_3(aq)$ vs $NH_4^+$) that influences AOA distribution, what happens if we apply the speciated forms to the energy supply calculations?

# %%
#Reloading required packages. 
import pandas as pd
import aqequil
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading speciation file made from the Figure_2_Data_Input file
speciation = aqequil.load("Total_Ammonia_Oxidation_Speciation.speciation")
# Out:
# Loaded 'Total_Ammonia_Oxidation_Speciation.speciation'

# %%
df_NH4 = speciation.calculate_energy(
        y_type = "E",
        y_units = "J",
        species = ["NH4+", "O2", "H+", "H2O", "NO2-"],
        stoich = [-1, -1.5, 2, 1, 1],
        as_written = True,
        rxn_name = "NH4+ Oxidation (J/kg)")

# %%
#Print energy calculations to a csv
df_NH4.to_csv("NH4+_Energy_Report.csv")

# %%
df_NH3 = speciation.calculate_energy(
        y_type = "E",
        y_units = "J",
        species = ["NH3", "O2", "H+", "H2O", "NO2-"],
        stoich = [-1, -1.5, 1, 1, 1],
        as_written = True,
        rxn_name = "NH3 Oxidation (J/kg)")

# %%
#Print energy calculations to a csv
df_NH3.to_csv("NH3_Energy_Report.csv")

# %%
#Reading in files
NH4_Energy = pd.read_csv("NH4+_Energy_Report.csv")
NH3_Energy = pd.read_csv("NH3_Energy_Report.csv")
Speciation_Data= pd.read_csv('Figure2_Data_Speciation_Report.csv')

#Merging data frames for ease of plotting
NH4_Energy_df = pd.merge(NH4_Energy, Speciation_Data , on='Sample')
NH3_Energy_df = pd.merge(NH3_Energy, Speciation_Data , on='Sample')

# %%
#Formatting data frames for plotting

#Removing the first row so we are only including headers and values
NH4_Energy_df = NH4_Energy_df.iloc[1:]

# List of columns to convert to float
columns = ['O2_(input)', 'NH4+ Oxidation (J/kg) energy supply']

# Convert the selected columns to floats
for c in columns:
    NH4_Energy_df[c] = NH4_Energy_df[c].astype(float)

# Display the updated DataFrame to check the changes
NH4_Energy_df.head()
# Out:
#      Sample  NH4+ Oxidation (J/kg) energy supply  \
# 1  140724SC                             5.248099
# 2  140724SD                             5.789693
# 3  140724SE                             5.033785
# 4  140725SI                             0.161660
# 5  140725SJ                             0.152086
#
#   NH4+ Oxidation (J/kg) limiting reactant    Year  AOA    AOA RA Temperature  \
# 1                                    NH4+  2014.0  Yes  3.137337        50.0
# 2                                    NH4+  2014.0  Yes  1.321815        54.8
# 3                                    NH4+  2014.0  Yes  5.339491        70.2
# 4                                    NH4+  2014.0  Yes  0.156292        59.2
# 5                                    NH4+  2014.0   No  0.000000        64.6
#
#              Pressure pH_(input) HCO3-_(input)  ... Mg+2_total  NH4+_total  \
# 1  1.0000000000000018      7.993      4.25E-04  ...   6.41e-06    2.29e-05
# 2                 1.0      7.745      4.71E-04  ...   6.79e-06    2.43e-05
# 3                 1.0       7.13      4.90E-04  ...   6.63e-06    1.99e-05
# 4                 1.0      9.034      3.10E-04  ...        NaN    3.19e-06
# 5                 1.0      9.044      3.58E-05  ...        NaN    4.01e-06
#
#   NO2-_total NO3-_total  Na+_total  O2_total    OH-_total PO4-3_total  \
# 1    1.7e-07   1.77e-07  0.0145001  8.13e-05  8.76217e-06    1.24e-07
# 2   2.08e-07   2.42e-07  0.0142611  7.19e-05          NaN    1.71e-07
# 3   4.62e-08   1.16e-07  0.0139516   7.5e-05          NaN         NaN
# 4   1.55e-07   9.35e-08  0.0136697   7.5e-05  0.000148773    1.34e-07
# 5   1.76e-07   7.42e-07  0.0137037  2.81e-05  0.000162242    1.23e-07
#
#    SO4-2_total SiO2_total
# 1   0.00110446   5.51e-06
# 2   0.00110134   5.31e-06
# 3   0.00107501   4.41e-06
# 4  0.000173258   7.97e-06
# 5  0.000172341   7.41e-06
#
# [5 rows x 252 columns]

# %%
#Formatting data frames for plotting

#Removing the first row so we are only including headers and values
NH3_Energy_df = NH3_Energy_df.iloc[1:]

# List of columns to convert to float
columns = ['O2_(input)', 'NH3 Oxidation (J/kg) energy supply']

# Convert the selected columns to floats
for c in columns:
    NH3_Energy_df[c] = NH3_Energy_df[c].astype(float)

# Display the updated DataFrame to check the changes
NH3_Energy_df.head()
# Out:
#      Sample  NH3 Oxidation (J/kg) energy supply  \
# 1  140724SC                            1.297346
# 2  140724SD                            1.074846
# 3  140724SE                            0.535729
# 4  140725SI                            0.764551
# 5  140725SJ                            0.996615
#
#   NH3 Oxidation (J/kg) limiting reactant    Year  AOA    AOA RA Temperature  \
# 1                                    NH3  2014.0  Yes  3.137337        50.0
# 2                                    NH3  2014.0  Yes  1.321815        54.8
# 3                                    NH3  2014.0  Yes  5.339491        70.2
# 4                                    NH3  2014.0  Yes  0.156292        59.2
# 5                                    NH3  2014.0   No  0.000000        64.6
#
#              Pressure pH_(input) HCO3-_(input)  ... Mg+2_total  NH4+_total  \
# 1  1.0000000000000018      7.993      4.25E-04  ...   6.41e-06    2.29e-05
# 2                 1.0      7.745      4.71E-04  ...   6.79e-06    2.43e-05
# 3                 1.0       7.13      4.90E-04  ...   6.63e-06    1.99e-05
# 4                 1.0      9.034      3.10E-04  ...        NaN    3.19e-06
# 5                 1.0      9.044      3.58E-05  ...        NaN    4.01e-06
#
#   NO2-_total NO3-_total  Na+_total  O2_total    OH-_total PO4-3_total  \
# 1    1.7e-07   1.77e-07  0.0145001  8.13e-05  8.76217e-06    1.24e-07
# 2   2.08e-07   2.42e-07  0.0142611  7.19e-05          NaN    1.71e-07
# 3   4.62e-08   1.16e-07  0.0139516   7.5e-05          NaN         NaN
# 4   1.55e-07   9.35e-08  0.0136697   7.5e-05  0.000148773    1.34e-07
# 5   1.76e-07   7.42e-07  0.0137037  2.81e-05  0.000162242    1.23e-07
#
#    SO4-2_total SiO2_total
# 1   0.00110446   5.51e-06
# 2   0.00110134   5.31e-06
# 3   0.00107501   4.41e-06
# 4  0.000173258   7.97e-06
# 5  0.000172341   7.41e-06
#
# [5 rows x 252 columns]

# %% [markdown]
# ## Figure 4a. AOA distribution as a function of $NH_4^+$ Oxidation energy supplies (cal/kg) and $O_2$ concentrations

# %%
# Set plot style
sns.set(style="whitegrid")

# Create a scatter plot
plt.figure(figsize=(10, 6))

#Setting marker shapes based on whether AOA were detected (Yes; triangles) or were not detected (No; 'X's)
markers= {"Yes": "^", "No": "X"}

# Plot with Seaborn, using 'hue' for point shapes
sns.scatterplot(
    data=NH4_Energy_df,
    x= 'O2_(input)',
    y='NH4+ Oxidation (J/kg) energy supply',
    style='AOA',  # Set different point shapes based on 'AOA'
    markers=markers,
    s = 200, #setting point size
)

# Add labels and title
plt.xlabel('Dissolved Oxygen (molality)')
plt.ylabel('NH4+ Oxidation Energy Supplies (J/kg)')

# Set the x-axis and y-axis to log scale
plt.xscale('log')
plt.yscale('log')

# Show the plot
plt.show()

# %% [markdown]
# Ammonia-oxidizers are not constrained by $NH_4^+$ oxidation energy supplies.

# %% [markdown]
# ## Figure 4b. AOA distribution as a function of $NH_3(aq)$ Oxidation energy supplies (cal/kg) and $O_2$ concentrations

# %%
# Set plot style
sns.set(style="whitegrid")

# Create a scatter plot
plt.figure(figsize=(10, 6))

#Setting marker shapes based on whether AOA were detected (Yes; triangles) or were not detected (No; 'X's)
markers= {"Yes": "^", "No": "X"}

# Plot with Seaborn, using 'hue' for point shapes
sns.scatterplot(
    data=NH3_Energy_df,
    x='O2_(input)',
    y='NH3 Oxidation (J/kg) energy supply',
    style='AOA',  # Set different point shapes based on 'AOA'
    markers=markers,
    s = 200, #setting point size
)

# Add labels and title
plt.xlabel('Dissolved Oxygen (molality)')
plt.ylabel('NH3(aq) Oxidation Energy Supplies (J/kg)')

# Set the x-axis and y-axis to log scale
plt.xscale('log')
plt.yscale('log')
plt.axhline(y=0.014)

# Show the plot
plt.show()

# %% [markdown]
# Ammonia-oxidizers are constrained to an energy supply for $NH_3(aq)$ oxidation > 0.014 J/kg.

# %% [markdown]
# # Part 5. If there is enough $NH_3(aq)$ and there is not too much $NH_4^+$, do we perfectly constrain for AOA?

# %%
#Reading in required file
Figure_2_Data_Combined = pd.read_csv("Figure_2_Data_Combined.csv")


#Reformatting
#Removing the first row so we are only including headers and values
Figure_2_Data_Combined = Figure_2_Data_Combined.iloc[1:]

# List of columns to convert to float
columns = ['NH3', 'NH4+']

# Convert the selected columns to floats
for c in columns:
    Figure_2_Data_Combined[c] = Figure_2_Data_Combined[c].astype(float)

# Display the updated DataFrame to check the changes
Figure_2_Data_Combined.head()
# Out:
#    Unnamed: 0    Sample  \
# 1           1  140724SC
# 2           2  140724SD
# 3           3  140724SE
# 4           4  140725SI
# 5           5  140725SJ
#
#   Total Dissolved Ammonia Oxidation (J/kg) energy supply  \
# 1                                  6.545446355229326
# 2                                 6.8645218979131295
# 3                                 5.5694887707711045
# 4                                 0.9261891133456535
# 5                                  1.148661113302747
#
#   Total Dissolved Ammonia Oxidation (J/kg) limiting reactant    Year  AOA  \
# 1                                               NH4+          2014.0  Yes
# 2                                               NH4+          2014.0  Yes
# 3                                               NH4+          2014.0  Yes
# 4                                               NH4+          2014.0  Yes
# 5                                               NH4+          2014.0   No
#
#      AOA RA Temperature            Pressure pH_(input)  ... Mg+2_total  \
# 1  3.137337        50.0  1.0000000000000018      7.993  ...   6.41e-06
# 2  1.321815        54.8                 1.0      7.745  ...   6.79e-06
# 3  5.339491        70.2                 1.0       7.13  ...   6.63e-06
# 4  0.156292        59.2                 1.0      9.034  ...        NaN
# 5  0.000000        64.6                 1.0      9.044  ...        NaN
#
#   NH4+_total NO2-_total NO3-_total  Na+_total  O2_total    OH-_total  \
# 1   2.29e-05    1.7e-07   1.77e-07  0.0145001  8.13e-05  8.76217e-06
# 2   2.43e-05   2.08e-07   2.42e-07  0.0142611  7.19e-05          NaN
# 3   1.99e-05   4.62e-08   1.16e-07  0.0139516   7.5e-05          NaN
# 4   3.19e-06   1.55e-07   9.35e-08  0.0136697   7.5e-05  0.000148773
# 5   4.01e-06   1.76e-07   7.42e-07  0.0137037  2.81e-05  0.000162242
#
#   PO4-3_total  SO4-2_total SiO2_total
# 1    1.24e-07   0.00110446   5.51e-06
# 2    1.71e-07   0.00110134   5.31e-06
# 3         NaN   0.00107501   4.41e-06
# 4    1.34e-07  0.000173258   7.97e-06
# 5    1.23e-07  0.000172341   7.41e-06
#
# [5 rows x 253 columns]

# %%
# Set plot style
sns.set(style="whitegrid")

# Create a scatter plot
plt.figure(figsize=(10, 6))

#Setting marker shapes based on whether AOA were detected (Yes; triangles) or were not detected (No; 'X's)
markers= {"Yes": "^", "No": "X"}

# Plot with Seaborn, using 'hue' for point shapes
sns.scatterplot(
    data=Figure_2_Data_Combined,
    x='NH4+',
    y='NH3',
    style='AOA',  # Set different point shapes based on 'AOA'
    markers=markers,
    s = 200, #setting point size
)

# Add labels and title
plt.xlabel('NH4+ (molality)')
plt.ylabel('NH3(aq) (molality)')

# Set the x-axis and y-axis to log scale
plt.xscale('log')
plt.yscale('log')
plt.axhline(y=0.00000007)
plt.axvline(x=0.0000205)

# Show the plot
plt.show()

# %% [markdown]
# Within the upper left-hand quadrant of the plot, there remain 13 samples where no AOA were detected despite sufficient $NH_3(aq)$ and tolerable NH4+ concentrations.  A potential explanation is these AOA absences are due to bioavailable copper limitations. Copper is a co-factor in the enzyme responsible for ammonia oxidation, ammonia monooxygenase, in AOA. Total copper concentrations among YNP hot springs are frequently near or below the detection limit reported by the USGS as ~8 nM concentrations. Although the copper requirements of *Ca. Nitrosocaldus* have not yet been described, the copper requirements for N. maritimus have been reported by Amin et al., (2013) to be at least 1 nM total copper. It has been established in marine settings that copper and iron abundances are key niche-defining geochemical variables for AOA. Further investigation is required to determine if the metal limitation findings from Amin et al. (2013) and Shafiee et al. (2021) are reflected in YNP hot spring AOA distributions.

# %% [markdown]
# # Conclusion

# %% [markdown]
# Neither the presence nor the abundance of AOA among YNP hot springs correlates with the energy supply for total dissolved ammonia oxidation. By investigating the distribution of hot spring AOA as functions of speciated abundances of $NH_3(aq)$ and NH4+, a substrate threshold concentration for NH3(aq) and an apparent maximum concentration for NH4+ are identified (0.07 μmolal and 20.5 μmolal, respectively). In addition, when speciated chemical abundances are used to calculate energy supplies, we observe a significant difference in AOA distribution at the NH3 oxidation energy supply threshold of 0.017 J kg-1 water. In combination, the distribution of AOA, specifically *Ca. Nitrosocaldus*, as functions of $NH_3(aq)$ and $NH_4^+$ concentrations and speciated energy supplies, defines the niche occupied by hot spring AOA. Ammonia oxidation offers an example of how using energy supplies can be misleading when calculated using total chemical abundances. In contrast, analyzing microbial distribution in terms of speciated chemical abundances and energy supplies, rather than focusing on pH and total abundances, helps identify boundaries for microbial presence and novel insights into substrate requirements and potential inhibitions.
